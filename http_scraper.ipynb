# %%
import json
import random
import asyncio
from datetime import datetime
from playwright.async_api import async_playwright

# CONFIG
seed_urls = [
    'https://example.com',
    'https://httpbin.org',
    'https://jsonplaceholder.typicode.com'
]
keywords = ['user', 'token', 'login', 'auth', 'api']
output_file = 'matched_api_calls.ndjson'

# Function to write to file in streaming mode
def append_to_file(data):
    with open(output_file, 'a') as f:
        f.write(json.dumps(data) + '\n')

async def intercept_requests(page):
    async def handle_request(route, request):
        try:
            url = request.url.lower()
            method = request.method.upper()
            resource_type = request.resource_type
            headers = request.headers
            post_data = await request.post_data() or ''
            timestamp = datetime.utcnow().isoformat()

            # Filter: ignore static resources
            if resource_type not in ['xhr', 'fetch']:
                await route.continue_()
                return

            # Check for keyword match
            if any(keyword in url for keyword in keywords) or \
               any(keyword in post_data.lower() for keyword in keywords) or \
               any(keyword in str(headers).lower() for keyword in keywords):
                
                metadata = {
                    'timestamp': timestamp,
                    'url': url,
                    'method': method,
                    'resource_type': resource_type,
                    'headers': headers,
                    'post_data': post_data,
                }
                print(f"[MATCH] {method} {url}")
                append_to_file(metadata)

            await route.continue_()
        except Exception as e:
            print(f"Error in handle_request: {e}")
            await route.continue_()

    await page.route("**/*", handle_request)

async def crawl_page(playwright, url):
    browser = await playwright.chromium.launch(headless=True)
    context = await browser.new_context()
    page = await context.new_page()
    await intercept_requests(page)

    try:
        await page.goto(url, timeout=20000)
        # Trigger some interactions
        await page.mouse.wheel(0, 500)  # Scroll down
        await page.wait_for_timeout(5000)
    except Exception as e:
        print(f"Error visiting {url}: {e}")
    
    await browser.close()

async def main():
    async with async_playwright() as playwright:
        urls_to_visit = random.sample(seed_urls, k=min(3, len(seed_urls)))
        for url in urls_to_visit:
            await crawl_page(playwright, url)

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 82
#      79             await crawl_page(playwright, url)
#      81 if __name__ == "__main__":
# ---> 82     asyncio.run(main())
#
# File /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     195     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
import json
import random
import asyncio
from datetime import datetime
from playwright.async_api import async_playwright

# CONFIG
seed_urls = [
    'https://example.com',
    'https://httpbin.org',
    'https://jsonplaceholder.typicode.com'
]
keywords = ['']
output_file = 'matched_api_calls.ndjson'

# Function to write to file in streaming mode
def append_to_file(data):
    with open(output_file, 'a') as f:
        f.write(json.dumps(data) + '\n')

async def intercept_requests(page):
    async def handle_request(route, request):
        try:
            url = request.url.lower()
            method = request.method.upper()
            resource_type = request.resource_type
            headers = request.headers
            post_data = await request.post_data() or ''
            timestamp = datetime.utcnow().isoformat()

            print(f"[DEBUG] {method} {url} ({resource_type})")

            # Filter: ignore static resources
            if resource_type not in ['xhr', 'fetch']:
                await route.continue_()
                return

            # Check for keyword match
            if any(keyword in url for keyword in keywords) or \
               any(keyword in post_data.lower() for keyword in keywords) or \
               any(keyword in str(headers).lower() for keyword in keywords):
                
                metadata = {
                    'timestamp': timestamp,
                    'url': url,
                    'method': method,
                    'resource_type': resource_type,
                    'headers': headers,
                    'post_data': post_data,
                }
                print(f"[MATCH] {method} {url}")
                append_to_file(metadata)

            await route.continue_()
        except Exception as e:
            print(f"Error in handle_request: {e}")
            await route.continue_()

    await page.route("**/*", handle_request)

async def crawl_page(playwright, url):
    browser = await playwright.chromium.launch(headless=True)
    context = await browser.new_context()
    page = await context.new_page()
    await intercept_requests(page)

    try:
        await page.goto(url, timeout=20000)
        # Trigger some interactions
        await page.mouse.wheel(0, 500)  # Scroll down
        await page.wait_for_timeout(5000)
    except Exception as e:
        print(f"Error visiting {url}: {e}")
    
    await browser.close()

async def main():
    async with async_playwright() as playwright:
        urls_to_visit = random.sample(seed_urls, k=min(3, len(seed_urls)))
        for url in urls_to_visit:
            await crawl_page(playwright, url)

# Safe event loop handling
if __name__ == "__main__":
    try:
        loop = asyncio.get_event_loop()
        if loop.is_running():
            # Already running (e.g., Jupyter or interactive shell)
            task = loop.create_task(main())
        else:
            loop.run_until_complete(main())
    except RuntimeError:
        # No event loop, start fresh
        asyncio.run(main())
# Out:
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'NoneType' object is not callable
# Error in handle_request: 'str' object is not callable

# %%
import json
import random
import asyncio
from datetime import datetime
from playwright.async_api import async_playwright

# CONFIG
seed_urls = [
    'https://jobcopilot.com/'
]
keywords = ['']
output_file = 'matched_api_calls.ndjson'

# Function to write to file in streaming mode
def append_to_file(data):
    with open(output_file, 'a') as f:
        f.write(json.dumps(data) + '\n')

async def intercept_requests(page):
    async def handle_request(route, request):
        try:
            url = request.url.lower()
            method = request.method.upper()
            resource_type = request.resource_type
            headers = request.headers
            timestamp = datetime.utcnow().isoformat()

            # Get post_data safely
            post_data = ''
            if method in ['POST', 'PUT', 'PATCH']:
                try:
                    post_data = await request.post_data() or ''
                except Exception:
                    post_data = ''

            # Debug: Print all requests
            print(f"[DEBUG] {method} {url} ({resource_type})")

            # Filter: ignore static resources
            if resource_type not in ['xhr', 'fetch']:
                await route.continue_()
                return

            # Check for keyword match
            if any(keyword in url for keyword in keywords) or \
               any(keyword in post_data.lower() for keyword in keywords) or \
               any(keyword in str(headers).lower() for keyword in keywords):
                
                metadata = {
                    'timestamp': timestamp,
                    'url': url,
                    'method': method,
                    'resource_type': resource_type,
                    'headers': headers,
                    'post_data': post_data,
                }
                print(f"[MATCH] {method} {url}")
                append_to_file(metadata)

            await route.continue_()
        except Exception as e:
            print(f"Error in handle_request: {e}")
            await route.continue_()

    await page.route("**/*", handle_request)

async def crawl_page(playwright, url):
    browser = await playwright.chromium.launch(headless=True)
    context = await browser.new_context()
    page = await context.new_page()
    await intercept_requests(page)

    try:
        print(f"[INFO] Visiting {url}")
        await page.goto(url, timeout=20000)
        # Trigger some interactions
        await page.mouse.wheel(0, 500)  # Scroll down
        await page.wait_for_timeout(5000)
    except Exception as e:
        print(f"Error visiting {url}: {e}")
    
    await browser.close()

async def main():
    async with async_playwright() as playwright:
        urls_to_visit = random.sample(seed_urls, k=min(3, len(seed_urls)))
        for url in urls_to_visit:
            await crawl_page(playwright, url)

# Robust event loop handling for scripts and Jupyter
try:
    loop = asyncio.get_event_loop()
    if loop.is_running():
        # Jupyter/interactive shell
        import nest_asyncio
        nest_asyncio.apply()
        loop.create_task(main())
    else:
        loop.run_until_complete(main())
except RuntimeError:
    asyncio.run(main())
# Out:
# [INFO] Visiting https://jobcopilot.com/
# [DEBUG] GET https://jobcopilot.com/ (document)
# /var/folders/k2/27m3rkmj3x50sfl14f2jympr0000gn/T/ipykernel_62946/1535328619.py:26: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   timestamp = datetime.utcnow().isoformat()
# [DEBUG] GET https://jobcopilot.com/wp-content/boost-cache/static/791334f676.min.css (stylesheet)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/translatepress-multilingual/assets/images/flags/en_us.png (image)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/translatepress-multilingual/assets/images/flags/de_de.png (image)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/translatepress-multilingual/assets/images/flags/es_es.png (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/03/250px.png?fit=250%2c75&ssl=1 (image)
# [DEBUG] GET https://g10102301085.co/gr?id=-o5muphajy_nhi4jtqjb&refurl=&winurl=https%3a%2f%2fjobcopilot.com%2f (script)
# [DEBUG] GET https://jobcopilot.com/wp-includes/js/jquery/jquery.min.js?ver=3.7.1 (script)
# [DEBUG] GET https://jobcopilot.com/wp-includes/js/jquery/jquery-migrate.min.js?m=1712932104 (script)
# [DEBUG] GET https://cdn.trackdesk.com/tracking.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/boost-cache/static/c501810c22.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/frontend.min.js?ver=3.29.1 (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/boost-cache/static/5e5e35a2ce.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-includes/js/dist/i18n.min.js?ver=5e580eb46a90c2b997e6 (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/frontend.min.js?ver=3.29.1 (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/elements-handlers.min.js?ver=3.29.1 (script)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/yahoo-finance-1.png?w=260&ssl=1 (image)
# [DEBUG] GET https://jobcopilot.com/wp-content/uploads/2024/06/product-hunt-logo-horizontal-black.avif (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/06/business-insider-logo.png?w=270&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/06/marketwatch-logo.png?w=696&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/get-more-interviews-with-job-application-automation.png?resize=300%2c300&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/automate-job-search.png?resize=300%2c300&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/automate-job-applications.png?resize=300%2c300&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/use-job-application-automation-to-save-time.png?resize=300%2c300&ssl=1 (image)
# [DEBUG] GET https://jobcopilot.com/wp-content/uploads/elementor/google-fonts/fonts/redhatdisplay-8viq7wur0m80wwyf0qcxzzyzuotg_t6h.woff2 (font)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/08/apply-to-real-jobs-on-jobcopilot.png?resize=300%2c300&ssl=1 (image)
# [DEBUG] GET https://www.googletagmanager.com/gtm.js?id=gtm-wklgwkdc (script)
# [DEBUG] GET https://www.googletagmanager.com/gtag/js?id=g-h6zch5x9qh&cx=c&gtm=45he55s2v9203866116za200&tag_exp=101509157~103116026~103200004~103233427~103252644~103252646~103351866~103351868~104481633~104481635~104559073~104559075~104612245~104612247 (script)
# [DEBUG] GET https://connect.facebook.net/en_us/fbevents.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/section-frontend-handlers.d85ab872da118940910d.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/shared-frontend-handlers.30dc2f9c080845a413a6.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/nav-menu.a23fbd67486c5bedf26c.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/form.5fb35271b8ba3fb1e7d6.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/popup.f7b15b2ca565b152bf98.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/text-editor.c084ef86600b6f11690d.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/carousel.3620fca501cb18163600.bundle.min.js (script)
# [DEBUG] POST https://www.google-analytics.com/g/collect?v=2&tid=g-h6zch5x9qh&gtm=45je55s2v9185764652z89203866116za200zb9203866116&_p=1748842286828&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=101509157~102938614~103116026~103200004~103233427~103252644~103252646~103351869~103351871~104481633~104481635~104559073~104559075~104612245~104612247&ptag_exp=101509157~103116026~103200004~103233427~103252644~103252646~103351866~103351868~104481633~104481635~104559073~104559075~104612245~104612247&cid=606073684.1748842287&ul=en-us&sr=1280x720&uaa=arm&uab=64&uafvl=chromium%3b136.0.7103.25%7cheadlesschrome%3b136.0.7103.25%7cnot.a%252fbrand%3b99.0.0.0&uamb=0&uam=&uap=macos&uapv=15.5.0&uaw=0&are=1&frm=0&pscdl=noapi&_s=1&sid=1748842287&sct=1&seg=0&dl=https%3a%2f%2fjobcopilot.com%2f&dt=automate%20job%20applications%20with%20ai%20-%20jobcopilot&en=page_view&_fv=1&_nsi=1&_ss=1&tfd=1897 (fetch)
# [MATCH] POST https://www.google-analytics.com/g/collect?v=2&tid=g-h6zch5x9qh&gtm=45je55s2v9185764652z89203866116za200zb9203866116&_p=1748842286828&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=101509157~102938614~103116026~103200004~103233427~103252644~103252646~103351869~103351871~104481633~104481635~104559073~104559075~104612245~104612247&ptag_exp=101509157~103116026~103200004~103233427~103252644~103252646~103351866~103351868~104481633~104481635~104559073~104559075~104612245~104612247&cid=606073684.1748842287&ul=en-us&sr=1280x720&uaa=arm&uab=64&uafvl=chromium%3b136.0.7103.25%7cheadlesschrome%3b136.0.7103.25%7cnot.a%252fbrand%3b99.0.0.0&uamb=0&uam=&uap=macos&uapv=15.5.0&uaw=0&are=1&frm=0&pscdl=noapi&_s=1&sid=1748842287&sct=1&seg=0&dl=https%3a%2f%2fjobcopilot.com%2f&dt=automate%20job%20applications%20with%20ai%20-%20jobcopilot&en=page_view&_fv=1&_nsi=1&_ss=1&tfd=1897
# [DEBUG] GET https://connect.facebook.net/signals/config/952475753695684?v=2.9.203&r=stable&domain=jobcopilot.com&hme=36c7454c4b078660353e5d4c89e3eaca439a56e5c3ceaadddff6c79ae427835a&ex_m=74%2c128%2c113%2c117%2c65%2c6%2c106%2c73%2c19%2c101%2c93%2c55%2c58%2c183%2c204%2c211%2c207%2c208%2c210%2c32%2c107%2c57%2c81%2c209%2c178%2c181%2c205%2c206%2c191%2c140%2c45%2c196%2c193%2c194%2c37%2c152%2c18%2c54%2c200%2c199%2c142%2c21%2c44%2c2%2c47%2c69%2c70%2c71%2c75%2c97%2c20%2c17%2c100%2c96%2c95%2c114%2c56%2c116%2c42%2c115%2c33%2c98%2c43%2c90%2c29%2c179%2c182%2c149%2c14%2c15%2c16%2c8%2c9%2c28%2c25%2c26%2c61%2c66%2c68%2c79%2c105%2c108%2c30%2c80%2c12%2c10%2c84%2c52%2c24%2c110%2c109%2c111%2c102%2c13%2c23%2c4%2c41%2c78%2c22%2c161%2c136%2c77%2c1%2c99%2c60%2c88%2c36%2c31%2c86%2c87%2c92%2c40%2c7%2c94%2c85%2c48%2c35%2c38%2c0%2c72%2c118%2c91%2c5%2c51%2c50%2c89%2c248%2c176%2c126%2c164%2c157%2c3%2c39%2c67%2c46%2c112%2c49%2c83%2c64%2c63%2c34%2c103%2c62%2c59%2c53%2c82%2c76%2c27%2c104%2c11%2c119 (script)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/jeremy-wiens-e1726994126470.jpeg?fit=100%2c100&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/abria-perry-e1726994117523.jpeg?fit=100%2c100&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/09/lukasdembicki-jobcopilot.jpg?fit=50%2c50&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/lorene-lim-e1726994107973.jpeg?fit=100%2c100&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/12/zach-zumpano-account-manager.jpg?fit=50%2c50&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/09/alexandria-chambers-jobcopilot.jpg?fit=50%2c50&ssl=1 (image)
# [DEBUG] GET https://www.facebook.com/tr/?id=952475753695684&ev=pageview&dl=https%3a%2f%2fjobcopilot.com%2f&rl=&if=false&ts=1748842287378&sw=1280&sh=720&v=2.9.203&r=stable&ec=0&o=12446&fbp=fb.1.1748842287378.925706761745015340&ler=empty&it=1748842287288&coo=false&rqm=get (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/job.png?w=64&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/profiles.png?w=64&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2025/04/train-ai-model-2.png?w=64&ssl=1 (image)

# %%
import json
import asyncio
from urllib.parse import urlparse, urljoin
from datetime import datetime
from playwright.async_api import async_playwright

# CONFIG
seed_urls = ['https://jobcopilot.com/']
keywords = []
output_file = 'matched_api_calls.ndjson'
visited_urls = set()
max_depth = 2  # Control crawl depth

def append_to_file(data):
    with open(output_file, 'a') as f:
        f.write(json.dumps(data) + '\n')

async def intercept_requests(page):
    async def handle_request(route, request):
        try:
            url = request.url.lower()
            method = request.method.upper()
            resource_type = request.resource_type
            headers = request.headers
            timestamp = datetime.utcnow().isoformat()

            # Get post_data safely
            post_data = ''
            if method in ['POST', 'PUT', 'PATCH']:
                try:
                    post_data = await request.post_data() or ''
                except Exception:
                    post_data = ''

            print(f"[DEBUG] {method} {url} ({resource_type})")

            if resource_type not in ['xhr', 'fetch']:
                await route.continue_()
                return

            if any(keyword in url for keyword in keywords) or \
               any(keyword in post_data.lower() for keyword in keywords) or \
               any(keyword in str(headers).lower() for keyword in keywords):

                metadata = {
                    'timestamp': timestamp,
                    'url': url,
                    'method': method,
                    'resource_type': resource_type,
                    'headers': headers,
                    'post_data': post_data,
                }
                print(f"[MATCH] {method} {url}")
                append_to_file(metadata)

            await route.continue_()
        except Exception as e:
            print(f"Error in handle_request: {e}")
            await route.continue_()

    await page.route("**/*", handle_request)

async def extract_links(page, base_url):
    anchors = await page.eval_on_selector_all("a", "els => els.map(el => el.href)")
    internal_links = set()
    parsed_base = urlparse(base_url)

    for link in anchors:
        parsed_link = urlparse(link)
        if parsed_link.netloc == parsed_base.netloc:
            clean_link = urljoin(base_url, parsed_link.path or '')
            internal_links.add(clean_link.rstrip('/'))

    return internal_links

async def crawl_page(playwright, url, depth):
    if url in visited_urls or depth > max_depth:
        return
    visited_urls.add(url)

    print(f"[INFO] Visiting {url}")
    browser = await playwright.chromium.launch(headless=True)
    context = await browser.new_context()
    page = await context.new_page()
    await intercept_requests(page)

    try:
        await page.goto(url, timeout=20000)
        await page.mouse.wheel(0, 500)
        await page.wait_for_timeout(3000)
        links = await extract_links(page, url)
    except Exception as e:
        print(f"Error visiting {url}: {e}")
        links = set()

    await browser.close()

    for link in links:
        await crawl_page(playwright, link, depth + 1)

async def main():
    async with async_playwright() as playwright:
        for url in seed_urls:
            await crawl_page(playwright, url, 0)

try:
    loop = asyncio.get_event_loop()
    if loop.is_running():
        import nest_asyncio
        nest_asyncio.apply()
        loop.create_task(main())
    else:
        loop.run_until_complete(main())
except RuntimeError:
    asyncio.run(main())
# Out:
# [INFO] Visiting https://jobcopilot.com/
# /var/folders/k2/27m3rkmj3x50sfl14f2jympr0000gn/T/ipykernel_62946/2214876196.py:25: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   timestamp = datetime.utcnow().isoformat()
# [DEBUG] GET https://jobcopilot.com/ (document)
# [DEBUG] GET https://jobcopilot.com/wp-content/boost-cache/static/791334f676.min.css (stylesheet)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/translatepress-multilingual/assets/images/flags/en_us.png (image)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/translatepress-multilingual/assets/images/flags/de_de.png (image)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/translatepress-multilingual/assets/images/flags/es_es.png (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/03/250px.png?fit=250%2c75&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/yahoo-finance-1.png?w=260&ssl=1 (image)
# [DEBUG] GET https://jobcopilot.com/wp-content/uploads/2024/06/product-hunt-logo-horizontal-black.avif (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/06/business-insider-logo.png?w=270&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/06/marketwatch-logo.png?w=696&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/get-more-interviews-with-job-application-automation.png?resize=300%2c300&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/automate-job-search.png?resize=300%2c300&ssl=1 (image)
# [DEBUG] GET https://g10102301085.co/gr?id=-o5muphajy_nhi4jtqjb&refurl=&winurl=https%3a%2f%2fjobcopilot.com%2f (script)
# [DEBUG] GET https://jobcopilot.com/wp-includes/js/jquery/jquery.min.js?ver=3.7.1 (script)
# [DEBUG] GET https://jobcopilot.com/wp-includes/js/jquery/jquery-migrate.min.js?m=1712932104 (script)
# [DEBUG] GET https://cdn.trackdesk.com/tracking.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/boost-cache/static/c501810c22.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/frontend.min.js?ver=3.29.1 (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/boost-cache/static/5e5e35a2ce.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-includes/js/dist/i18n.min.js?ver=5e580eb46a90c2b997e6 (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/frontend.min.js?ver=3.29.1 (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/elements-handlers.min.js?ver=3.29.1 (script)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/automate-job-applications.png?resize=300%2c300&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/use-job-application-automation-to-save-time.png?resize=300%2c300&ssl=1 (image)
# [DEBUG] GET https://jobcopilot.com/wp-content/uploads/elementor/google-fonts/fonts/redhatdisplay-8viq7wur0m80wwyf0qcxzzyzuotg_t6h.woff2 (font)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/08/apply-to-real-jobs-on-jobcopilot.png?resize=300%2c300&ssl=1 (image)
# [DEBUG] GET https://www.googletagmanager.com/gtm.js?id=gtm-wklgwkdc (script)
# [DEBUG] GET https://www.googletagmanager.com/gtag/js?id=g-h6zch5x9qh&cx=c&gtm=45he55s2v9203866116za200&tag_exp=101509157~103116026~103200004~103233427~103252644~103252646~103351866~103351868~104481633~104481635~104559073~104559075~104612245~104612247 (script)
# [DEBUG] GET https://connect.facebook.net/en_us/fbevents.js (script)
# [DEBUG] POST https://www.google-analytics.com/g/collect?v=2&tid=g-h6zch5x9qh&gtm=45je55s2v9185764652z89203866116za200zb9203866116&_p=1748842417232&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=101509157~103116026~103200004~103233427~103252644~103252646~103351869~103351871~104481633~104481635~104559073~104559075~104612245~104612247&ptag_exp=101509157~103116026~103200004~103233427~103252644~103252646~103351866~103351868~104481633~104481635~104559073~104559075~104612245~104612247&cid=1604012876.1748842418&ul=en-us&sr=1280x720&uaa=arm&uab=64&uafvl=chromium%3b136.0.7103.25%7cheadlesschrome%3b136.0.7103.25%7cnot.a%252fbrand%3b99.0.0.0&uamb=0&uam=&uap=macos&uapv=15.5.0&uaw=0&are=1&frm=0&pscdl=noapi&_s=1&sid=1748842417&sct=1&seg=0&dl=https%3a%2f%2fjobcopilot.com%2f&dt=automate%20job%20applications%20with%20ai%20-%20jobcopilot&en=page_view&_fv=1&_nsi=1&_ss=1&tfd=1770 (fetch)
# [MATCH] POST https://www.google-analytics.com/g/collect?v=2&tid=g-h6zch5x9qh&gtm=45je55s2v9185764652z89203866116za200zb9203866116&_p=1748842417232&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=101509157~103116026~103200004~103233427~103252644~103252646~103351869~103351871~104481633~104481635~104559073~104559075~104612245~104612247&ptag_exp=101509157~103116026~103200004~103233427~103252644~103252646~103351866~103351868~104481633~104481635~104559073~104559075~104612245~104612247&cid=1604012876.1748842418&ul=en-us&sr=1280x720&uaa=arm&uab=64&uafvl=chromium%3b136.0.7103.25%7cheadlesschrome%3b136.0.7103.25%7cnot.a%252fbrand%3b99.0.0.0&uamb=0&uam=&uap=macos&uapv=15.5.0&uaw=0&are=1&frm=0&pscdl=noapi&_s=1&sid=1748842417&sct=1&seg=0&dl=https%3a%2f%2fjobcopilot.com%2f&dt=automate%20job%20applications%20with%20ai%20-%20jobcopilot&en=page_view&_fv=1&_nsi=1&_ss=1&tfd=1770
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/section-frontend-handlers.d85ab872da118940910d.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/shared-frontend-handlers.30dc2f9c080845a413a6.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/nav-menu.a23fbd67486c5bedf26c.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/form.5fb35271b8ba3fb1e7d6.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/popup.f7b15b2ca565b152bf98.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/text-editor.c084ef86600b6f11690d.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/carousel.3620fca501cb18163600.bundle.min.js (script)
# [DEBUG] GET https://connect.facebook.net/signals/config/952475753695684?v=2.9.203&r=stable&domain=jobcopilot.com&hme=36c7454c4b078660353e5d4c89e3eaca439a56e5c3ceaadddff6c79ae427835a&ex_m=74%2c128%2c113%2c117%2c65%2c6%2c106%2c73%2c19%2c101%2c93%2c55%2c58%2c183%2c204%2c211%2c207%2c208%2c210%2c32%2c107%2c57%2c81%2c209%2c178%2c181%2c205%2c206%2c191%2c140%2c45%2c196%2c193%2c194%2c37%2c152%2c18%2c54%2c200%2c199%2c142%2c21%2c44%2c2%2c47%2c69%2c70%2c71%2c75%2c97%2c20%2c17%2c100%2c96%2c95%2c114%2c56%2c116%2c42%2c115%2c33%2c98%2c43%2c90%2c29%2c179%2c182%2c149%2c14%2c15%2c16%2c8%2c9%2c28%2c25%2c26%2c61%2c66%2c68%2c79%2c105%2c108%2c30%2c80%2c12%2c10%2c84%2c52%2c24%2c110%2c109%2c111%2c102%2c13%2c23%2c4%2c41%2c78%2c22%2c161%2c136%2c77%2c1%2c99%2c60%2c88%2c36%2c31%2c86%2c87%2c92%2c40%2c7%2c94%2c85%2c48%2c35%2c38%2c0%2c72%2c118%2c91%2c5%2c51%2c50%2c89%2c248%2c176%2c126%2c164%2c157%2c3%2c39%2c67%2c46%2c112%2c49%2c83%2c64%2c63%2c34%2c103%2c62%2c59%2c53%2c82%2c76%2c27%2c104%2c11%2c119 (script)
# [DEBUG] GET https://www.facebook.com/tr/?id=952475753695684&ev=pageview&dl=https%3a%2f%2fjobcopilot.com%2f&rl=&if=false&ts=1748842417647&sw=1280&sh=720&v=2.9.203&r=stable&ec=0&o=12446&fbp=fb.1.1748842417646.41133835357032003&ler=empty&it=1748842417613&coo=false&rqm=get (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/jeremy-wiens-e1726994126470.jpeg?fit=100%2c100&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/abria-perry-e1726994117523.jpeg?fit=100%2c100&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/09/lukasdembicki-jobcopilot.jpg?fit=50%2c50&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/lorene-lim-e1726994107973.jpeg?fit=100%2c100&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/12/zach-zumpano-account-manager.jpg?fit=50%2c50&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/09/alexandria-chambers-jobcopilot.jpg?fit=50%2c50&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/job.png?w=64&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/05/profiles.png?w=64&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2025/04/train-ai-model-2.png?w=64&ssl=1 (image)
# [INFO] Visiting https://jobcopilot.com/about-us
# [DEBUG] GET https://jobcopilot.com/about-us (document)
# [DEBUG] GET https://jobcopilot.com/wp-content/boost-cache/static/0b1332fc77.min.css (stylesheet)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/03/250px.png?fit=250%2c75&ssl=1 (image)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/translatepress-multilingual/assets/images/flags/en_us.png (image)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/translatepress-multilingual/assets/images/flags/de_de.png (image)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/translatepress-multilingual/assets/images/flags/es_es.png (image)
# [DEBUG] GET https://g10102301085.co/gr?id=-o5muphajy_nhi4jtqjb&refurl=&winurl=https%3a%2f%2fjobcopilot.com%2fabout-us%2f (script)
# [DEBUG] GET https://jobcopilot.com/wp-includes/js/jquery/jquery.min.js?ver=3.7.1 (script)
# [DEBUG] GET https://jobcopilot.com/wp-includes/js/jquery/jquery-migrate.min.js?m=1712932104 (script)
# [DEBUG] GET https://cdn.trackdesk.com/tracking.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/boost-cache/static/c501810c22.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/frontend.min.js?ver=3.29.1 (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/boost-cache/static/4d832d5212.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-includes/js/dist/i18n.min.js?ver=5e580eb46a90c2b997e6 (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/frontend.min.js?ver=3.29.1 (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/elements-handlers.min.js?ver=3.29.1 (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/uploads/elementor/google-fonts/fonts/redhatdisplay-8viq7wur0m80wwyf0qcxzzyzuotg_t6h.woff2 (font)
# [DEBUG] GET https://www.googletagmanager.com/gtm.js?id=gtm-wklgwkdc (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/section-frontend-handlers.d85ab872da118940910d.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/shared-frontend-handlers.30dc2f9c080845a413a6.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/nav-menu.a23fbd67486c5bedf26c.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/text-editor.c084ef86600b6f11690d.bundle.min.js (script)
# [DEBUG] GET https://www.googletagmanager.com/gtag/js?id=g-h6zch5x9qh&cx=c&gtm=45he55s2h1v9203866116za200&tag_exp=101509157~103116026~103200004~103233427~103252644~103252646~103351866~103351868~104481633~104481635~104559073~104559075~104612245~104612247 (script)
# [DEBUG] GET https://connect.facebook.net/en_us/fbevents.js (script)
# [DEBUG] POST https://www.google-analytics.com/g/collect?v=2&tid=g-h6zch5x9qh&gtm=45je55s2h1v9185764652z89203866116za200zb9203866116&_p=1748842423437&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=101509157~102015666~103116026~103200004~103233427~103252644~103252646~103351866~103351868~104481633~104481635~104559073~104559075~104612245~104612247&ptag_exp=101509157~103116026~103200004~103233427~103252644~103252646~103351866~103351868~104481633~104481635~104559073~104559075~104612245~104612247&cid=622043929.1748842424&ul=en-us&sr=1280x720&uaa=arm&uab=64&uafvl=chromium%3b136.0.7103.25%7cheadlesschrome%3b136.0.7103.25%7cnot.a%252fbrand%3b99.0.0.0&uamb=0&uam=&uap=macos&uapv=15.5.0&uaw=0&are=1&frm=0&pscdl=noapi&_s=1&sid=1748842423&sct=1&seg=0&dl=https%3a%2f%2fjobcopilot.com%2fabout-us%2f&dt=about%20us%20-%20jobcopilot&en=page_view&_fv=1&_nsi=1&_ss=1&tfd=2631 (fetch)
# [MATCH] POST https://www.google-analytics.com/g/collect?v=2&tid=g-h6zch5x9qh&gtm=45je55s2h1v9185764652z89203866116za200zb9203866116&_p=1748842423437&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=101509157~102015666~103116026~103200004~103233427~103252644~103252646~103351866~103351868~104481633~104481635~104559073~104559075~104612245~104612247&ptag_exp=101509157~103116026~103200004~103233427~103252644~103252646~103351866~103351868~104481633~104481635~104559073~104559075~104612245~104612247&cid=622043929.1748842424&ul=en-us&sr=1280x720&uaa=arm&uab=64&uafvl=chromium%3b136.0.7103.25%7cheadlesschrome%3b136.0.7103.25%7cnot.a%252fbrand%3b99.0.0.0&uamb=0&uam=&uap=macos&uapv=15.5.0&uaw=0&are=1&frm=0&pscdl=noapi&_s=1&sid=1748842423&sct=1&seg=0&dl=https%3a%2f%2fjobcopilot.com%2fabout-us%2f&dt=about%20us%20-%20jobcopilot&en=page_view&_fv=1&_nsi=1&_ss=1&tfd=2631
# [DEBUG] GET https://connect.facebook.net/signals/config/952475753695684?v=2.9.203&r=stable&domain=jobcopilot.com&hme=36c7454c4b078660353e5d4c89e3eaca439a56e5c3ceaadddff6c79ae427835a&ex_m=74%2c128%2c113%2c117%2c65%2c6%2c106%2c73%2c19%2c101%2c93%2c55%2c58%2c183%2c204%2c211%2c207%2c208%2c210%2c32%2c107%2c57%2c81%2c209%2c178%2c181%2c205%2c206%2c191%2c140%2c45%2c196%2c193%2c194%2c37%2c152%2c18%2c54%2c200%2c199%2c142%2c21%2c44%2c2%2c47%2c69%2c70%2c71%2c75%2c97%2c20%2c17%2c100%2c96%2c95%2c114%2c56%2c116%2c42%2c115%2c33%2c98%2c43%2c90%2c29%2c179%2c182%2c149%2c14%2c15%2c16%2c8%2c9%2c28%2c25%2c26%2c61%2c66%2c68%2c79%2c105%2c108%2c30%2c80%2c12%2c10%2c84%2c52%2c24%2c110%2c109%2c111%2c102%2c13%2c23%2c4%2c41%2c78%2c22%2c161%2c136%2c77%2c1%2c99%2c60%2c88%2c36%2c31%2c86%2c87%2c92%2c40%2c7%2c94%2c85%2c48%2c35%2c38%2c0%2c72%2c118%2c91%2c5%2c51%2c50%2c89%2c248%2c176%2c126%2c164%2c157%2c3%2c39%2c67%2c46%2c112%2c49%2c83%2c64%2c63%2c34%2c103%2c62%2c59%2c53%2c82%2c76%2c27%2c104%2c11%2c119 (script)
# [DEBUG] GET https://www.facebook.com/tr/?id=952475753695684&ev=pageview&dl=https%3a%2f%2fjobcopilot.com%2fabout-us%2f&rl=&if=false&ts=1748842423759&sw=1280&sh=720&v=2.9.203&r=stable&ec=0&o=12446&fbp=fb.1.1748842423759.565254305930955677&ler=empty&it=1748842423732&coo=false&exp=k0&rqm=get (image)
# [INFO] Visiting https://jobcopilot.com/reviews
# [DEBUG] GET https://jobcopilot.com/reviews (document)
# [DEBUG] GET https://jobcopilot.com/wp-content/boost-cache/static
20-%20jobcopilot&en=page_view&_fv=1&_nsi=1&_ss=1&tfd=2534
# [DEBUG] GET https://connect.facebook.net/signals/config/952475753695684?v=2.9.203&r=stable&domain=jobcopilot.com&hme=36c7454c4b078660353e5d4c89e3eaca439a56e5c3ceaadddff6c79ae427835a&ex_m=74%2c128%2c113%2c117%2c65%2c6%2c106%2c73%2c19%2c101%2c93%2c55%2c58%2c183%2c204%2c211%2c207%2c208%2c210%2c32%2c107%2c57%2c81%2c209%2c178%2c181%2c205%2c206%2c191%2c140%2c45%2c196%2c193%2c194%2c37%2c152%2c18%2c54%2c200%2c199%2c142%2c21%2c44%2c2%2c47%2c69%2c70%2c71%2c75%2c97%2c20%2c17%2c100%2c96%2c95%2c114%2c56%2c116%2c42%2c115%2c33%2c98%2c43%2c90%2c29%2c179%2c182%2c149%2c14%2c15%2c16%2c8%2c9%2c28%2c25%2c26%2c61%2c66%2c68%2c79%2c105%2c108%2c30%2c80%2c12%2c10%2c84%2c52%2c24%2c110%2c109%2c111%2c102%2c13%2c23%2c4%2c41%2c78%2c22%2c161%2c136%2c77%2c1%2c99%2c60%2c88%2c36%2c31%2c86%2c87%2c92%2c40%2c7%2c94%2c85%2c48%2c35%2c38%2c0%2c72%2c118%2c91%2c5%2c51%2c50%2c89%2c248%2c176%2c126%2c164%2c157%2c3%2c39%2c67%2c46%2c112%2c49%2c83%2c64%2c63%2c34%2c103%2c62%2c59%2c53%2c82%2c76%2c27%2c104%2c11%2c119 (script)
# [DEBUG] GET https://www.facebook.com/tr/?id=952475753695684&ev=pageview&dl=https%3a%2f%2fjobcopilot.com%2fautomate-job-applications%2f&rl=&if=false&ts=1748842440815&sw=1280&sh=720&v=2.9.203&r=stable&ec=0&o=12446&fbp=fb.1.1748842440814.848012468849709016&ler=empty&it=1748842440786&coo=false&rqm=get (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2025/04/train-your-copilot.png?w=640&ssl=1 (image)
# [INFO] Visiting https://jobcopilot.com/terms
# [DEBUG] GET https://jobcopilot.com/terms (document)
# Task exception was never retrieved
# future: <Task finished name='Task-19' coro=<main() done, defined at /var/folders/k2/27m3rkmj3x50sfl14f2jympr0000gn/T/ipykernel_62946/2212627003.py:77> exception=Error("BrowserType.launch: Executable doesn't exist at /Users/yashchhabria/Library/Caches/ms-playwright/chromium_headless_shell-1169/chrome-mac/headless_shell\n╔════════════════════════════════════════════════════════════╗\n║ Looks like Playwright was just installed or updated.       ║\n║ Please run the following command to download new browsers: ║\n║                                                            ║\n║     playwright install                                     ║\n║                                                            ║\n║ <3 Playwright Team                                         ║\n╚════════════════════════════════════════════════════════════╝")>
# Traceback (most recent call last):
#   File "/var/folders/k2/27m3rkmj3x50sfl14f2jympr0000gn/T/ipykernel_62946/2212627003.py", line 81, in main
#     await crawl_page(playwright, url)
#   File "/var/folders/k2/27m3rkmj3x50sfl14f2jympr0000gn/T/ipykernel_62946/2212627003.py", line 62, in crawl_page
#     browser = await playwright.chromium.launch(headless=True)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/yashchhabria/Projects/http_scraper/.venv/lib/python3.13/site-packages/playwright/async_api/_generated.py", line 14451, in launch
#     await self._impl_obj.launch(
#     ...<17 lines>...
#     )
#   File "/Users/yashchhabria/Projects/http_scraper/.venv/lib/python3.13/site-packages/playwright/_impl/_browser_type.py", line 97, in launch
#     Browser, from_channel(await self._channel.send("launch", params))
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/yashchhabria/Projects/http_scraper/.venv/lib/python3.13/site-packages/playwright/_impl/_connection.py", line 61, in send
#     return await self._connection.wrap_api_call(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<2 lines>...
#     )
#     ^
#   File "/Users/yashchhabria/Projects/http_scraper/.venv/lib/python3.13/site-packages/playwright/_impl/_connection.py", line 528, in wrap_api_call
#     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
# playwright._impl._errors.Error: BrowserType.launch: Executable doesn't exist at /Users/yashchhabria/Library/Caches/ms-playwright/chromium_headless_shell-1169/chrome-mac/headless_shell
# ╔════════════════════════════════════════════════════════════╗
# ║ Looks like Playwright was just installed or updated.       ║
# ║ Please run the following command to download new browsers: ║
# ║                                                            ║
# ║     playwright install                                     ║
# ║                                                            ║
# ║ <3 Playwright Team                                         ║
# ╚════════════════════════════════════════════════════════════╝
# [DEBUG] GET https://jobcopilot.com/wp-content/boost-cache/static/e91f438249.min.css (stylesheet)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/03/250px.png?fit=250%2c75&ssl=1 (image)
# [DEBUG] GET https://g10102301085.co/gr?id=-o5muphajy_nhi4jtqjb&refurl=&winurl=https%3a%2f%2fjobcopilot.com%2fterms%2f (script)
# [DEBUG] GET https://jobcopilot.com/wp-includes/js/jquery/jquery.min.js?ver=3.7.1 (script)
# [DEBUG] GET https://jobcopilot.com/wp-includes/js/jquery/jquery-migrate.min.js?m=1712932104 (script)
# [DEBUG] GET https://cdn.trackdesk.com/tracking.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/boost-cache/static/c501810c22.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/frontend.min.js?ver=3.29.1 (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/boost-cache/static/4d832d5212.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-includes/js/dist/i18n.min.js?ver=5e580eb46a90c2b997e6 (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/frontend.min.js?ver=3.29.1 (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/elements-handlers.min.js?ver=3.29.1 (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/uploads/elementor/google-fonts/fonts/redhatdisplay-8viq7wur0m80wwyf0qcxzzyzuotg_t6h.woff2 (font)
# [DEBUG] GET https://www.googletagmanager.com/gtm.js?id=gtm-wklgwkdc (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/section-frontend-handlers.d85ab872da118940910d.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/shared-frontend-handlers.30dc2f9c080845a413a6.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor-pro/assets/js/nav-menu.a23fbd67486c5bedf26c.bundle.min.js (script)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/elementor/assets/js/text-editor.c084ef86600b6f11690d.bundle.min.js (script)
# [DEBUG] GET https://www.googletagmanager.com/gtag/js?id=g-h6zch5x9qh&cx=c&gtm=45he55s2v9203866116za200&tag_exp=101509157~103116026~103200004~103233427~103252644~103252646~103351866~103351868~104481633~104481635~104559073~104559075~104612245~104612247 (script)
# [DEBUG] GET https://connect.facebook.net/en_us/fbevents.js (script)
# [DEBUG] POST https://www.google-analytics.com/g/collect?v=2&tid=g-h6zch5x9qh&gtm=45je55s2v9185764652z89203866116za200zb9203866116&_p=1748842446394&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=101509157~103116026~103200004~103211513~103233427~103252644~103252646~103351869~103351871~104481633~104481635~104559073~104559075~104612245~104612247&ptag_exp=101509157~103116026~103200004~103233427~103252644~103252646~103351866~103351868~104481633~104481635~104559073~104559075~104612245~104612247&cid=2099461635.1748842447&ul=en-us&sr=1280x720&uaa=arm&uab=64&uafvl=chromium%3b136.0.7103.25%7cheadlesschrome%3b136.0.7103.25%7cnot.a%252fbrand%3b99.0.0.0&uamb=0&uam=&uap=macos&uapv=15.5.0&uaw=0&are=1&frm=0&pscdl=noapi&_s=1&sid=1748842446&sct=1&seg=0&dl=https%3a%2f%2fjobcopilot.com%2fterms%2f&dt=terms%20-%20jobcopilot&en=page_view&_fv=1&_nsi=1&_ss=1&tfd=2522 (fetch)
# [MATCH] POST https://www.google-analytics.com/g/collect?v=2&tid=g-h6zch5x9qh&gtm=45je55s2v9185764652z89203866116za200zb9203866116&_p=1748842446394&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=101509157~103116026~103200004~103211513~103233427~103252644~103252646~103351869~103351871~104481633~104481635~104559073~104559075~104612245~104612247&ptag_exp=101509157~103116026~103200004~103233427~103252644~103252646~103351866~103351868~104481633~104481635~104559073~104559075~104612245~104612247&cid=2099461635.1748842447&ul=en-us&sr=1280x720&uaa=arm&uab=64&uafvl=chromium%3b136.0.7103.25%7cheadlesschrome%3b136.0.7103.25%7cnot.a%252fbrand%3b99.0.0.0&uamb=0&uam=&uap=macos&uapv=15.5.0&uaw=0&are=1&frm=0&pscdl=noapi&_s=1&sid=1748842446&sct=1&seg=0&dl=https%3a%2f%2fjobcopilot.com%2fterms%2f&dt=terms%20-%20jobcopilot&en=page_view&_fv=1&_nsi=1&_ss=1&tfd=2522
# [DEBUG] GET https://connect.facebook.net/signals/config/952475753695684?v=2.9.203&r=stable&domain=jobcopilot.com&hme=36c7454c4b078660353e5d4c89e3eaca439a56e5c3ceaadddff6c79ae427835a&ex_m=74%2c128%2c113%2c117%2c65%2c6%2c106%2c73%2c19%2c101%2c93%2c55%2c58%2c183%2c204%2c211%2c207%2c208%2c210%2c32%2c107%2c57%2c81%2c209%2c178%2c181%2c205%2c206%2c191%2c140%2c45%2c196%2c193%2c194%2c37%2c152%2c18%2c54%2c200%2c199%2c142%2c21%2c44%2c2%2c47%2c69%2c70%2c71%2c75%2c97%2c20%2c17%2c100%2c96%2c95%2c114%2c56%2c116%2c42%2c115%2c33%2c98%2c43%2c90%2c29%2c179%2c182%2c149%2c14%2c15%2c16%2c8%2c9%2c28%2c25%2c26%2c61%2c66%2c68%2c79%2c105%2c108%2c30%2c80%2c12%2c10%2c84%2c52%2c24%2c110%2c109%2c111%2c102%2c13%2c23%2c4%2c41%2c78%2c22%2c161%2c136%2c77%2c1%2c99%2c60%2c88%2c36%2c31%2c86%2c87%2c92%2c40%2c7%2c94%2c85%2c48%2c35%2c38%2c0%2c72%2c118%2c91%2c5%2c51%2c50%2c89%2c248%2c176%2c126%2c164%2c157%2c3%2c39%2c67%2c46%2c112%2c49%2c83%2c64%2c63%2c34%2c103%2c62%2c59%2c53%2c82%2c76%2c27%2c104%2c11%2c119 (script)
# [DEBUG] GET https://www.facebook.com/tr/?id=952475753695684&ev=pageview&dl=https%3a%2f%2fjobcopilot.com%2fterms%2f&rl=&if=false&ts=1748842446737&sw=1280&sh=720&v=2.9.203&r=stable&ec=0&o=12446&fbp=fb.1.1748842446737.901309917379392793&ler=empty&it=1748842446705&coo=false&rqm=get (image)
# [INFO] Visiting https://jobcopilot.com/business
# [DEBUG] GET https://jobcopilot.com/business (document)
# [DEBUG] GET https://jobcopilot.com/wp-content/boost-cache/static/4666423472.min.css (stylesheet)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/translatepress-multilingual/assets/images/flags/en_us.png (image)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/translatepress-multilingual/assets/images/flags/de_de.png (image)
# [DEBUG] GET https://jobcopilot.com/wp-content/plugins/translatepress-multilingual/assets/images/flags/es_es.png (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/03/250px.png?fit=250%2c75&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024/12/top-5-tools-to-autofill-job-applications.png?resize=768%2c432&ssl=1 (image)
# [DEBUG] GET https://i0.wp.com/jobcopilot.com/wp-content/uploads/2024
# [DEBUG] GET https://www.facebook.com/tr/?id=952475753695684&ev=pageview&dl=https%3a%2f%2fjobcopilot.com%2fde%2fkarrierewechsel-berater%2f&rl=&if=false&ts=1748842699605&sw=1280&sh=720&v=2.9.203&r=stable&ec=0&o=12446&fbp=fb.1.1748842699605.498471491598076339&ler=empty&it=1748842699573&coo=false&exp=k0&rqm=get (image)

# %%
import json
import asyncio
import re
from urllib.parse import urlparse, urljoin
from datetime import datetime
from playwright.async_api import async_playwright

# CONFIG
seed_urls = [
    "https://typingmind.com/",
    "https://mygpt.ai/",
    "https://halist.ai/",
    "https://chatpad.ai/",
    "https://github.com/aws-samples/bedrock-claude-chat",
    "https://jan.ai/",
    "https://github.com/sindresorhus/awesome-chatgpt",
    "https://www.reddit.com/r/gptwrappers/"
]
keywords = ['converstations','o4','claude','gemini']
output_file = 'matched_api_calls.ndjson'
visited_urls = set()
max_depth = 2

def append_to_file(data):
    with open(output_file, 'a') as f:
        f.write(json.dumps(data) + '\n')

def is_keyword_match(url):
    return any(keyword in url for keyword in keywords)

def extract_links_from_text(text):
    return set(re.findall(r'https?://[^\s"\'<>]+', text))

async def intercept_requests(page):
    async def handle_request(route, request):
        try:
            url = request.url.lower()
            method = request.method.upper()
            resource_type = request.resource_type
            headers = {k.lower(): v.lower() for k, v in request.headers.items()}
            timestamp = datetime.utcnow().isoformat()

            post_data = ''
            if method in ['POST', 'PUT', 'PATCH']:
                try:
                    post_data = (await request.post_data() or '').lower()
                except Exception:
                    post_data = ''

            if resource_type not in ['xhr', 'fetch']:
                await route.continue_()
                return

            if any(keyword in url for keyword in keywords) or \
               any(keyword in post_data for keyword in keywords) or \
               any(keyword in str(headers) for keyword in keywords):

                metadata = {
                    'timestamp': timestamp,
                    'url': url,
                    'method': method,
                    'resource_type': resource_type,
                    'headers': headers,
                    'post_data': post_data,
                }
                print(f"[MATCH] {method} {url}")
                append_to_file(metadata)

            await route.continue_()
        except Exception as e:
            print(f"Error in handle_request: {e}")
            await route.continue_()

    await page.route("**/*", handle_request)

async def extract_links(page, base_url):
    anchors = await page.eval_on_selector_all("a", "els => els.map(el => el.href)")
    text_content = await page.content()

    extracted = set()
    parsed_base = urlparse(base_url)

    # From <a href>
    for link in anchors:
        parsed_link = urlparse(link)
        clean_link = urljoin(base_url, parsed_link.path or '').rstrip('/')
        if parsed_link.scheme.startswith("http") and (parsed_link.netloc == parsed_base.netloc or is_keyword_match(link.lower())):
            extracted.add(clean_link)

    # From raw page text (e.g., Reddit posts)
    text_links = extract_links_from_text(text_content)
    for link in text_links:
        if is_keyword_match(link.lower()):
            extracted.add(link.rstrip('/'))

    return extracted

async def crawl_page(playwright, url, depth):
    if url in visited_urls or depth > max_depth:
        return
    visited_urls.add(url)

    print(f"[INFO] Visiting {url}")
    browser = await playwright.chromium.launch(headless=True)
    context = await browser.new_context()
    page = await context.new_page()
    await intercept_requests(page)

    try:
        await page.goto(url, timeout=20000)
        await page.mouse.wheel(0, 500)
        await page.wait_for_timeout(3000)
        links = await extract_links(page, url)
    except Exception as e:
        print(f"Error visiting {url}: {e}")
        links = set()

    await browser.close()

    for link in links:
        await crawl_page(playwright, link, depth + 1)

async def main():
    async with async_playwright() as playwright:
        for url in seed_urls:
            await crawl_page(playwright, url, 0)

try:
    loop = asyncio.get_event_loop()
    if loop.is_running():
        import nest_asyncio
        nest_asyncio.apply()
        loop.create_task(main())
    else:
        loop.run_until_complete(main())
except RuntimeError:
    asyncio.run(main())
# Out:
# [INFO] Visiting https://typingmind.com/
# /var/folders/k2/27m3rkmj3x50sfl14f2jympr0000gn/T/ipykernel_69047/2125770067.py:41: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   timestamp = datetime.utcnow().isoformat()
# [INFO] Visiting https://typingmind.com/tools/estimate-llm-usage-costs
# [MATCH] POST https://www.typingmind.com/_vercel/insights/view
# [INFO] Visiting https://custom.typingmind.com/tools/estimate-llm-usage-costs/?ref=typingmind
# [MATCH] POST https://custom.typingmind.com/_vercel/insights/view
# [INFO] Visiting https://custom.typingmind.com/case-studies/i22
# [INFO] Visiting https://custom.typingmind.com/careers
# [INFO] Visiting https://custom.typingmind.com/use-cases/for-enterprises
# [INFO] Visiting https://custom.typingmind.com/case-studies/traffic-builders
# [INFO] Visiting https://custom.typingmind.com/use-cases/for-education
# [INFO] Visiting https://custom.typingmind.com/use-cases/for-product-development
# [INFO] Visiting https://custom.typingmind.com/GDPR
# [INFO] Visiting https://custom.typingmind.com/tools/model-icons
# [INFO] Visiting https://custom.typingmind.com/data-processing-agreement
# [INFO] Visiting https://custom.typingmind.com/case-studies
# [INFO] Visiting https://custom.typingmind.com/features/custom-branding
# [INFO] Visiting https://custom.typingmind.com/tools/estimate-llm-usage-costs/gemini-1.5-flash-8b
# [MATCH] POST https://custom.typingmind.com/_vercel/insights/view
# [INFO] Visiting https://custom.typingmind.com/case-studies/pixelmechanics
# [INFO] Visiting https://custom.typingmind.com/tools/estimate-llm-usage-costs/claude-3-haiku
# [MATCH] POST https://custom.typingmind.com/_vercel/insights/view
# [INFO] Visiting https://custom.typingmind.com/tools/estimate-llm-usage-costs/gpt-4
# [MATCH] POST https://custom.typingmind.com/_vercel/insights/view
# [INFO] Visiting https://custom.typingmind.com/features/get-started-on-our-cloud
# [INFO] Visiting https://custom.typingmind.com/case-studies/orcavanloon
# [INFO] Visiting https://custom.typingmind.com/terms-of-service
# [INFO] Visiting https://custom.typingmind.com/privacy
# [INFO] Visiting https://custom.typingmind.com/use-cases/for-customer-support
# [INFO] Visiting https://custom.typingmind.com/tools/estimate-llm-usage-costs/pixtral-large-latest
# [MATCH] POST https://custom.typingmind.com/_vercel/insights/view
# [INFO] Visiting https://image.social/get?url=custom.typingmind.com/tools/estimate-llm-usage-costs
# [INFO] Visiting https://custom.typingmind.com/tools/estimate-llm-usage-costs/o1-mini
# [MATCH] POST https://custom.typingmind.com/_vercel/insights/view
# [INFO] Visiting https://custom.typingmind.com/tools/gen-ai-quiz
# [INFO] Visiting https://custom.typingmind.com/tools/estimate-llm-usage-costs/o1-preview
# [MATCH] POST https://custom.typingmind.com/_vercel/insights/view
# [INFO] Visiting https://custom.typingmind.com/case-studies/atomicobject
# [INFO] Visiting https://custom.typingmind.com/faqs
# [INFO] Visiting https://custom.typingmind.com/use-cases/agencies-consultants
# [INFO] Visiting https://custom.typingmind.com/tools
# [INFO] Visiting https://custom.typingmind.com/use-cases/marketing
# [INFO] Visiting https://custom.typingmind.com/tools/estimate-llm-usage-costs/gpt-3.5-turbo
# [MATCH] POST https://custom.typingmind.com/_vercel/insights/view
# [INFO] Visiting https://custom.typingmind.com/features/api-access
# [INFO] Visiting https://custom.typingmind.com/business-plan
# [INFO] Visiting https://custom.typingmind.com/tools/estimate-llm-usage-costs/gpt-4o-mini
# [MATCH] POST https://custom.typingmind.com/_vercel/insights/view
# [INFO] Visiting https://custom.typingmind.com/use-cases/for-small-medium-teams
# [INFO] Visiting https://custom.typingmind.com/features/upload-training-data
# [INFO] Visiting https://mygpt.ai/
# [INFO] Visiting https://chatpad.ai/
# [INFO] Visiting https://chatpad.ai
# [INFO] Visiting https://github.com/aws-samples/bedrock-claude-chat
# [INFO] Visiting https://github.com/statefb
# [INFO] Visiting https://github.com/features/issues
# [INFO] Visiting https://github.com/resources/whitepapers
# [INFO] Visiting https://github.com/features/models
# [INFO] Visiting https://github.com/premium-support
# [INFO] Visiting https://github.com/features/discussions
# [INFO] Visiting https://github.com/topics
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat
# [INFO] Visiting https://github.com/statefb/dtwalign/stargazers
# [INFO] Visiting https://github.com/resources/articles
# [INFO] Visiting https://github.com/resources/articles/ai
# [INFO] Visiting https://github.com/contact/report-abuse
# [INFO] Visiting https://github.com/aws-samples/knowledge-transfer-by-genai
# [INFO] Visiting https://github.com
# [INFO] Visiting https://github.com/features/code-review
# [INFO] Visiting https://github.com/solutions/use-case/devops
# [INFO] Visiting https://github.com/statefb/singular-spectrum-transformation
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/stargazers
# [MATCH] GET https://github.com/aws-samples/bedrock-chat/security/overall-count
# [INFO] Visiting https://github.com/features/copilot
# [INFO] Visiting https://github.com/awslabs/generative-ai-cdk-constructs
# [INFO] Visiting https://github.com/solutions/industry/nonprofits
# [INFO] Visiting https://github.com/solutions/industry/healthcare
# [INFO] Visiting https://github.com/customer-stories
# [INFO] Visiting https://github.com/solutions/industry/financial-services
# [INFO] Visiting https://github.com/statefb/dtwalign
# [INFO] Visiting https://github.com/statefb/singular-spectrum-transformation/forks
# [INFO] Visiting https://github.com/statefb/dtwalign/forks
# [INFO] Visiting https://github.com/SallyChamberOrchestra
# [INFO] Visiting https://github.com/statefb/singular-spectrum-transformation/stargazers

# %%
import json
import asyncio
from urllib.parse import urlparse, urljoin
from datetime import datetime
from playwright.async_api import async_playwright

# CONFIG
seed_urls = [
    "https://typingmind.com/",
    "https://mygpt.ai/",
    "https://halist.ai/",
    "https://chatpad.ai/",
    "https://github.com/aws-samples/bedrock-claude-chat",
    "https://jan.ai/",
    "https://github.com/sindresorhus/awesome-chatgpt",
    "https://www.reddit.com/r/gptwrappers/"
]
keywords = ['converstations', 'o4', 'claude', 'gemini']
output_file = 'matched_api_calls_req_body.ndjson'
visited_urls = set()
max_depth = 2

def append_to_file(data):
    with open(output_file, 'a') as f:
        f.write(json.dumps(data) + '\n')

async def intercept_requests(page):
    async def handle_request(route, request):
        try:
            url = request.url.lower()
            method = request.method.upper()
            resource_type = request.resource_type
            headers = {k.lower(): v.lower() for k, v in request.headers.items()}
            timestamp = datetime.utcnow().isoformat()

            # Only check body (POST/PUT/PATCH)
            post_data = ''
            if method in ['POST', 'PUT', 'PATCH']:
                try:
                    post_data = (await request.post_data() or '').lower()
                except Exception:
                    post_data = ''

                if any(keyword in post_data for keyword in keywords):
                    metadata = {
                        'timestamp': timestamp,
                        'url': url,
                        'method': method,
                        'headers': headers,
                        'post_data': post_data,
                    }
                    print(f"[MATCH] {method} {url}")
                    append_to_file(metadata)

            await route.continue_()
        except Exception as e:
            print(f"Error in handle_request: {e}")
            await route.continue_()

    await page.route("**/*", handle_request)

async def extract_links(page, base_url):
    anchors = await page.eval_on_selector_all("a", "els => els.map(el => el.href)")
    text_content = await page.content()

    extracted = set()
    parsed_base = urlparse(base_url)

    # From <a href>
    for link in anchors:
        parsed_link = urlparse(link)
        clean_link = urljoin(base_url, parsed_link.path or '').rstrip('/')
        if parsed_link.scheme.startswith("http"):
            extracted.add(clean_link)

    return extracted

async def crawl_page(playwright, url, depth):
    if url in visited_urls or depth > max_depth:
        return
    visited_urls.add(url)

    print(f"[INFO] Visiting {url}")
    browser = await playwright.chromium.launch(headless=True)
    context = await browser.new_context()
    page = await context.new_page()
    await intercept_requests(page)

    try:
        await page.goto(url, timeout=20000)
        await page.mouse.wheel(0, 500)
        await page.wait_for_timeout(3000)
        links = await extract_links(page, url)
    except Exception as e:
        print(f"Error visiting {url}: {e}")
        links = set()

    await browser.close()

    for link in links:
        await crawl_page(playwright, link, depth + 1)

async def main():
    async with async_playwright() as playwright:
        for url in seed_urls:
            await crawl_page(playwright, url, 0)

try:
    loop = asyncio.get_event_loop()
    if loop.is_running():
        import nest_asyncio
        nest_asyncio.apply()
        loop.create_task(main())
    else:
        loop.run_until_complete(main())
except RuntimeError:
    asyncio.run(main())
# Out:
# [INFO] Visiting https://typingmind.com/
# /var/folders/k2/27m3rkmj3x50sfl14f2jympr0000gn/T/ipykernel_75317/2055845771.py:34: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   timestamp = datetime.utcnow().isoformat()
# [INFO] Visiting https://typingmind.com/privacy
# [INFO] Visiting https://typingmind.com/GDPR
# [INFO] Visiting https://typingmind.com/company/typingmind
# [INFO] Visiting https://typingmind.com/about-us
# [INFO] Visiting https://typingmind.com/case-studies/eugeniuses
# [INFO] Visiting https://typingmind.com/faqs
# [INFO] Visiting https://typingmind.com/use-cases/for-enterprises
# [INFO] Visiting https://typingmind.com/use-cases/for-ecommerce-and-retail
# [INFO] Visiting https://typingmind.com/case-studies/agentiiv
# [INFO] Visiting https://typingmind.com/@TypingMind
# [INFO] Visiting https://typingmind.com/use-cases/for-customer-support
# [INFO] Visiting https://typingmind.com/case-studies/pixelmechanics
# [INFO] Visiting https://typingmind.com/tools/gen-ai-quiz
# [INFO] Visiting https://typingmind.com/case-studies/ask-alpha
# [INFO] Visiting https://typingmind.com/terms
# [INFO] Visiting https://typingmind.com/use-cases/agencies-consultants
# [INFO] Visiting https://typingmind.com/case-studies/traffic-builders
# [INFO] Visiting https://typingmind.com/case-studies/ithq
# [INFO] Visiting https://typingmind.com/data-processing-agreement
# [INFO] Visiting https://typingmind.com/contact
# [INFO] Visiting https://typingmind.com/use-cases/marketing
# [INFO] Visiting https://typingmind.com/reseller
# [INFO] Visiting https://typingmind.com/case-studies/i22
# [INFO] Visiting https://typingmind.com/use-cases/sales
# [INFO] Visiting https://typingmind.com/case-studies/mention-me
# [INFO] Visiting https://typingmind.com/case-studies/innogames
# [INFO] Visiting https://typingmind.com/buy
# [INFO] Visiting https://typingmind.com/use-cases/for-education
# [INFO] Visiting https://typingmind.com/use-cases/for-product-development
# [INFO] Visiting https://typingmind.com/typingmind
# [INFO] Visiting https://typingmind.com/case-studies/atomicobject
# [INFO] Visiting https://typingmind.com/tools/model-icons
# [INFO] Visiting https://typingmind.com/use-cases/for-learning-and-development
# [INFO] Visiting https://typingmind.com/tools/landing-page-audit
# [INFO] Visiting https://typingmind.com/careers
# [INFO] Visiting https://typingmind.com/changelog
# [INFO] Visiting https://typingmind.com/case-studies/entrepreneurs-circle
# [INFO] Visiting https://typingmind.com/TypingMindApp
# [INFO] Visiting https://typingmind.com/tools/estimate-llm-usage-costs
# [INFO] Visiting https://typingmind.com/use-cases/for-small-medium-teams
# [INFO] Visiting https://typingmind.com
# [INFO] Visiting https://typingmind.com/privacy-policy
# [INFO] Visiting https://typingmind.com/products/typing-mind/reviews
# [INFO] Visiting https://typingmind.com/products/typingmind-typingmind/reviews/typingmind-review-10399318
# [INFO] Visiting https://typingmind.com/p/10014630/TypingMind/reviews/Capterra___6208289
# [INFO] Visiting https://typingmind.com/reviews/65dbd13f97ad0ee49f6d78ca
# [INFO] Visiting https://typingmind.com/reviews/65d972bc0e621a74b0b42bd0
# [INFO] Visiting https://mygpt.ai/
# [INFO] Visiting https://halist.ai/
# [INFO] Visiting https://halist.ai/terms
# [INFO] Visiting https://halist.ai/mac
# [INFO] Visiting https://halist.ai/pricing
# [INFO] Visiting https://halist.ai
# [INFO] Visiting https://halist.ai/chrome
# [INFO] Visiting https://halist.ai/privacy
# [INFO] Visiting https://halist.ai/amix3k
# [INFO] Visiting https://halist.ai/app
# [INFO] Visiting https://halist.ai/login
# [INFO] Visiting https://chatpad.ai/
# [INFO] Visiting https://chatpad.ai
# [INFO] Visiting https://chatpad.ai/deiucanta/chatpad
# [INFO] Visiting https://chatpad.ai/230313oyppkw40a
# [INFO] Visiting https://chatpad.ai/deiucanta
# [INFO] Visiting https://github.com/aws-samples/bedrock-claude-chat
# [INFO] Visiting https://github.com/solutions/use-case/devops
# [INFO] Visiting https://github.com/solutions/use-case/devsecops
# [INFO] Visiting https://github.com/git-guides
# [INFO] Visiting https://github.com/devops/2024-gartner-mq-for-devops-platforms
# [INFO] Visiting https://github.com/login
# [INFO] Visiting https://github.com/solutions/industry/financial-services
# [INFO] Visiting https://github.com/resources/articles/software-development
# [INFO] Visiting https://github.com/customer-stories
# [INFO] Visiting https://github.com/solutions/industry/manufacturing
# [INFO] Visiting https://github.com/features/models
# [INFO] Visiting https://github.com/company/github
# [INFO] Visiting https://github.com/github/roadmap
# [INFO] Visiting https://github.com/collections
# [INFO] Visiting https://github.com/security
# [INFO] Visiting https://github.com/enterprise
# [INFO] Visiting https://github.com/solutions/industry/government
# [INFO] Visiting https://github.com/get-started/exploring-integrations/about-building-integrations
# [INFO] Visiting https://github.com/@github
# [INFO] Visiting https://github.com/organizations/enterprise_plan
# [INFO] Visiting https://github.com/software-development/innersource
# [INFO] Visiting https://github.com/features/copilot
# [INFO] Visiting https://github.com/features/issues
# [INFO] Visiting https://github.com/topics
# [INFO] Visiting https://github.com/solutions/industry
# [INFO] Visiting https://github.com/resources/whitepapers
# [INFO] Visiting https://github.com/features/copilot/copilot-business
# [INFO] Visiting https://github.com/2022-09-07-research-quantifying-github-copilots-impact-on-developer-productivity-and-happiness
# [INFO] Visiting https://github.com/edu
# [INFO] Visiting https://github.com/why-github
# [INFO] Visiting https://github.com/about
# [INFO] Visiting https://github.com/features/actions
# [INFO] Visiting https://github.com/resources/articles/security
# [INFO] Visiting https://github.com/features/code-review
# [INFO] Visiting https://github.com/solutions
# [INFO] Visiting https://github.com/resources/articles/ai
# [INFO] Visiting https://github.com/resources/articles
# [INFO] Visiting https://github.com/about/diversity
# [INFO] Visiting https://github.com/site-policy/github-terms/github-terms-of-service
# [INFO] Visiting https://github.com/site-policy/privacy-policies/github-privacy-statement
# [INFO] Visiting https://github.com
# [INFO] Visiting https://github.com/pricing
# [INFO] Visiting https://github.com/solutions/use-case/ci-cd
# [INFO] Visiting https://github.com/trending
# [INFO] Visiting https://github.com/premium-support
# [INFO] Visiting https://github.com/features/ai
# [INFO] Visiting https://github.com/reprints
# [INFO] Visiting https://github.com/resources/articles/devops/what-is-devops
# [INFO] Visiting https://github.com/readme
# [INFO] Visiting https://github.com/search-github/github-code-search/understanding-github-code-search-syntax
# [INFO] Visiting https://github.com/sitemap
# [INFO] Visiting https://github.com/solutions/industry/nonprofits
# [INFO] Visiting https://github.com/enterprise/premium-support
# [INFO] Visiting https://github.com/enterprise/startups
# [INFO] Visiting https://github.com/newsletter
# [INFO] Visiting https://github.com/features
# [INFO] Visiting https://github.com/signup
# [INFO] Visiting https://github.com/features/code-search
# [INFO] Visiting https://github.com/github
# [INFO] Visiting https://github.com/team
# [INFO] Visiting https://github.com/enterprise/contact
# [INFO] Visiting https://github.com/solutions/industry/healthcare
# [INFO] Visiting https://github.com/sponsors
# [INFO] Visiting https://github.com/newsroom
# [INFO] Visiting https://github.com/security/advanced-security
# [INFO] Visiting https://github.com/github/site-policy/pull/582
# [INFO] Visiting https://github.com/features/codespaces
# [INFO] Visiting https://github.com/solutions/use-case
# [INFO] Visiting https://github.com/resources/articles/devops
# [INFO] Visiting https://github.com/features/discussions
# [INFO] Visiting https://github.com/devops/tools/compare
# [INFO] Visiting https://github.com/mobile
# [INFO] Visiting https://github.com/learn/pathways
# [INFO] Visiting https://github.com/solutions/executive-insights
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/docs/imgs/import_existing_kb.png
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/projects
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/pulse
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/tree/v3/docs
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/.github/CODEOWNERS
# [INFO] Visiting https://github.com/aws-samples
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/commit/677fe466b9be7a7ff1abd0ce1f5baa64e0c68306
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/security
# [INFO] Visiting https://github.com/statefb
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/commits/v3/docs/imgs/import_existing_kb.png
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/commits
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/issues
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/tree/v3
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/actions
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/pulls
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/tree/v3/docs/imgs
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/search
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/issues/872
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/issues/866
# [INFO] Visiting https://github.com/search/advanced
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/issues/855
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/issues/857
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/issues/856
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/issues/848
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/issues/863
# [INFO] Visiting https://github.com/issues
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/issues/869
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/issues/870
# [INFO] Visiting https://github.com/search
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/issues/871
# [INFO] Visiting https://github.com/topics/chatbot
# [INFO] Visiting https://github.com/topics/chatchat
# [INFO] Visiting https://github.com/topics/openai-chatgpt
# [INFO] Visiting https://github.com/topics/agentic-ai
# [INFO] Visiting https://github.com/chatchat-space/Langchain-Chatchat/pulls
# [INFO] Visiting https://github.com/topics/rag
# [INFO] Visiting https://github.com/topics/mcp
# [INFO] Visiting https://github.com/topics/knowledgebase
# [INFO] Visiting https://github.com/topics/vuejs3
# [INFO] Visiting https://github.com/Cinnamon
# [INFO] Visiting https://github.com/topics/bot-framework
# [INFO] Visiting https://github.com/topics/llama2
# [INFO] Visiting https://github.com/topics/wechaty
# [INFO] Visiting https://github.com/topics/langchain
# [INFO] Visiting https://github.com/topics/windows
# [INFO] Visiting https://github.com/infiniflow/ragflow/discussions
# [INFO] Visiting https://github.com/sponsors/explore
# [INFO] Visiting https://github.com/f
# [INFO] Visiting https://github.com/haotian-liu/LLaVA/pulls
# [INFO] Visiting https://github.com/topics/eliza
# [INFO] Visiting https://github.com/topics/conversational-ai
# [INFO] Visiting https://github.com/topics/desktop-app
# [INFO] Visiting https://github.com/topics/vision-language-model
# [INFO] Visiting https://github.com/topics/maxkb
# [INFO] Visiting https://github.com/topics/artificial-intelligence
# [INFO] Visiting https://github.com/topics/genai
# [INFO] Visiting https://github.com/elizaOS/eliza/issues
# [INFO] Visiting https://github.com/yamadashy/repomix/discussions
# [INFO] Visiting https://github.com/sponsors/f
# [INFO] Visiting https://github.com/topics/mcp-server
# [INFO] Visiting https://github.com/topics/vuetify3
# [INFO] Visiting https://github.com/topics/openai
# [INFO] Visiting https://github.com/topics/llama-2
# [INFO] Visiting https://github.com/topics/vector-index
# [INFO] Visiting https://github.com/topics/low-code
# [INFO] Visiting https://github.com/python-telegram-bot/python-telegram-bot/discussions
# [INFO] Visiting https://github.com/topics/no-code
# [INFO] Visiting https://github.com/wechaty/wechaty/discussions
# [INFO] Visiting https://github.com/topics/linux
# [INFO] Visiting https://github.com/RasaHQ/rasa/pulls
# [INFO] Visiting https://github.com/infiniflow/ragflow
# [INFO] Visiting https://github.com/topics/api
# [INFO] Visiting https://github.com/topics/deepseek
# [INFO] Visiting https://github.com/topics/chatgpt-4
# [INFO] Visiting https://github.com/topics/hacktoberfest
# [INFO] Visiting https://github.com/topics/docker
# [INFO] Visiting https://github.com/topics/whatsapp
# [INFO] Visiting https://github.com/haotian-liu
# [INFO] Visiting https://github.com/wechaty/wechaty
# [INFO] Visiting https://github.com/mayooear/ai-pdf-chatbot-langchain/discussions
# [INFO] Visiting https://github.com/QuivrHQ/quivr/issues
# [INFO] Visiting https://github.com/topics/automation
# [INFO] Visiting https://github.com/topics/gpt4-api
# [INFO] Visiting https://github.com/topics/vector-database
# [INFO] Visiting https://github.com/f/awesome-chatgpt-prompts/pulls
# [INFO] Visiting https://github.com/python-telegram-bot
# [INFO] Visiting https://github.com/topics/language
# [INFO] Visiting https://github.com/topics/llm
# [INFO] Visiting https://github.com/topics/developer-tools
# [INFO] Visiting https://github.com/topics/llm-local
# [INFO] Visiting https://github.com/topics/copilot
# [INFO] Visiting https://github.com/topics/xinference
# [INFO] Visiting https://github.com/pathwaycom/llm-app/discussions
# [INFO] Visiting https://github.com/topics/offline
# [INFO] Visiting https://github.com/FlowiseAI/Flowise
# [INFO] Visiting https://github.com/mayooear/ai-pdf-chatbot-langchain
# [INFO] Visiting https://github.com/topics/text-to-speech
# [INFO] Visiting https://github.com/topics/chatbots
# [INFO] Visiting https://github.com/topics/framework
# [INFO] Visiting https://github.com/haotian-liu/LLaVA
# [INFO] Visiting https://github.com/elizaOS/eliza
# [INFO] Visiting https://github.com/topics/deepseek-r1
# [INFO] Visiting https://github.com/pathwaycom/llm-app
# [INFO] Visiting https://github.com/topics/llama
# [INFO] Visiting https://github.com/haotian-liu/LLaVA/issues
# [INFO] Visiting https://github.com/elizaOS
# [INFO] Visiting https://github.com/topics/conversational-agents
# [INFO] Visiting https://github.com/topics/retrieval-augmented-generation
# [INFO] Visiting https://github.com/topics/typescript
# [INFO] Visiting https://github.com/topics/mitie
# [INFO] Visiting https://github.com/topics/autonomous
# [INFO] Visiting https://github.com/wiki/Chatbot
# [INFO] Visiting https://github.com/topics/chatgpt-free
# [INFO] Visiting https://github.com/topics/robotics
# [INFO] Visiting https://github.com/topics/assistant
# [INFO] Visiting https://github.com/topics/postgresql
# [INFO] Visiting https://github.com/topics/ollama
# [INFO] Visiting https://github.com/infiniflow/ragflow/issues
# [INFO] Visiting https://github.com/chatboxai/chatbox/issues
# [INFO] Visiting https://github.com/wechaty/wechaty/pulls
# [INFO] Visiting https://github.com/topics/telegram
# [INFO] Visiting https://github.com/leon-ai
# [INFO] Visiting https://github.com/FlowiseAI/Flowise/discussions
# [INFO] Visiting https://github.com/topics/multi-modality
# [INFO] Visiting https://github.com/7q8NBZbQzt
# [INFO] Visiting https://github.com/xtekky/gpt4free/discussions
# [INFO] Visiting https://github.com/topics/reverse-engineering
# [INFO] Visiting https://github.com/topics/crypto
# [INFO] Visiting https://github.com/Cinnamon/kotaemon/pulls
# [INFO] Visiting https://github.com/sponsors/yamadashy
# [INFO] Visiting https://github.com/ai-shifu/ChatALL/issues
# [INFO] Visiting https://github.com/leon-ai/leon
# [INFO] Visiting https://github.com/leon-ai/leon/pulls
# [INFO] Visiting https://github.com/xtekky/gpt4free/pulls
# [INFO] Visiting https://github.com/topics/elizaos
# [INFO] Visiting https://github.com/topics/multiagent-systems
# [INFO] Visiting https://github.com/topics/ai-assistant
# [INFO] Visiting https://github.com/python-telegram-bot/python-telegram-bot/issues
# [INFO] Visiting https://github.com/mayooear/ai-pdf-chatbot-langchain/issues
# [INFO] Visiting https://github.com/topics/open-ai
# [INFO] Visiting https://github.com/ai-shifu
# [INFO] Visiting https://github.com/RasaHQ/rasa/issues
# [INFO] Visiting https://github.com/topics/gpt-4o
# [INFO] Visiting https://github.com/python-telegram-bot/python-telegram-bot/pulls
# [INFO] Visiting https://github.com/topics/chatbotai
# [INFO] Visiting https://github.com/chatboxai/chatbox
# [INFO] Visiting https://github.com/topics/conversation-driven-development
# [INFO] Visiting https://github.com/chatboxai/chatbox/pulls
# [INFO] Visiting https://github.com/topics/gpt4
# [INFO] Visiting https://github.com/topics/groq
# [INFO] Visiting https://github.com/xtekky/gpt4free/issues
# [INFO] Visiting https://github.com/QuivrHQ/quivr
# [INFO] Visiting https://github.com/topics/python
# [INFO] Visiting https://github.com/events
# [INFO] Visiting https://github.com/topics/gpt
# [INFO] Visiting https://github.com/topics/botkit
# [INFO] Visiting https://github.com/topics/agentic-workflow
# [INFO] Visiting https://github.com/topics/knowledge-base
# [INFO] Visiting https://github.com/wechaty
# [INFO] Visiting https://github.com/topics/real-time
# [INFO] Visiting https://github.com/topics/bots
# [INFO] Visiting https://github.com/topics/pathway
# [INFO] Visiting https://github.com/topics/chatgpt
# [INFO] Visiting https://github.com/topics/openai-api
# [INFO] Visiting https://github.com/topics/nextjs
# [INFO] Visiting https://github.com/Cinnamon/kotaemon
# [INFO] Visiting https://github.com/FlowiseAI
# [INFO] Visiting https://github.com/topics/chatgpt4
# [INFO] Visiting https://github.com/topics/open-source
# [INFO] Visiting https://github.com/topics/llm-security
# [INFO] Visiting https://github.com/sponsors/xtekky
# [INFO] Visiting https://github.com/CherryHQ/cherry-studio/issues
# [INFO] Visiting https://github.com/topics/multimodal
# [INFO] Visiting https://github.com/topics/privacy
# [INFO] Visiting https://github.com/topics/database
# [INFO] Visiting https://github.com/topics/voice-assistant
# [INFO] Visiting https://github.com/topics/qwen
# [INFO] Visiting https://github.com/topics/slack
# [INFO] Visiting https://github.com/1Panel-dev/MaxKB/discussions
# [INFO] Visiting https://github.com/1Panel-dev/MaxKB/pulls
# [INFO] Visiting https://github.com/topics/swarm
# [INFO] Visiting https://github.com/topics/agent
# [INFO] Visiting https://github.com/sponsors/FlowiseAI
# [INFO] Visiting https://github.com/topics/react
# [INFO] Visiting https://github.com/1Panel-dev/MaxKB/issues
# [INFO] Visiting https://github.com/topics/milvus
# [INFO] Visiting https://github.com/topics/faiss
# [INFO] Visiting https://github.com/topics/speech-recognition
# [INFO] Visiting https://github.com/topics/generative-ai
# [INFO] Visiting https://github.com/topics/flite
# [INFO] Visiting https://github.com/f/awesome-chatgpt-prompts/issues
# [INFO] Visiting https://github.com/QuivrHQ
# [INFO] Visiting https://github.com/elizaOS/eliza/discussions
# [INFO] Visiting https://github.com/topics/speech-synthesis
# [INFO] Visiting https://github.com/topics/pdf-to-text
# [INFO] Visiting https://github.com/Cinnamon/kotaemon/issues
# [INFO] Visiting https://github.com/topics/foundation-models
# [INFO] Visiting https://github.com/topics/claude
# [INFO] Visiting https://github.com/topics/llama3
# [INFO] Visiting https://github.com/topics/streamlit
# [INFO] Visiting https://github.com/topics/nlp
# [INFO] Visiting https://github.com/yamadashy/repomix/pulls
# [INFO] Visiting https://github.com/1Panel-dev/MaxKB
# [INFO] Visiting https://github.com/topics/llmops
# [INFO] Visiting https://github.com/RasaHQ
# [INFO] Visiting https://github.com/topics/gpt-4
# [INFO] Visiting https://github.com/topics/machine-learning
# [INFO] Visiting https://github.com/topics/deepseek-api
# [INFO] Visiting https://github.com/wechaty/wechaty/issues
# [INFO] Visiting https://github.com/ai-shifu/ChatALL
# [INFO] Visiting https://github.com/topics/llm-prompting
# [INFO] Visiting https://github.com/topics/instruction-tuning
# [INFO] Visiting https://github.com/topics/workflow-automation
# [INFO] Visiting https://github.com/mayooear
# [INFO] Visiting https://github.com/CherryHQ/cherry-studio
# [INFO] Visiting https://github.com/f/awesome-chatgpt-prompts
# [INFO] Visiting https://github.com/topics/vector
# [INFO] Visiting https://github.com/RasaHQ/rasa
# [INFO] Visiting https://github.com/topics/large-language-models
# [INFO] Visiting https://github.com/topics/document-parser
# [INFO] Visiting https://github.com/pathwaycom/llm-app/issues
# [INFO] Visiting https://github.com/topics/pgvector
# [INFO] Visiting https://github.com/infiniflow/ragflow/pulls
# [INFO] Visiting https://github.com/chatboxai
# [INFO] Visiting https://github.com/topics/rasa
# [INFO] Visiting https://github.com/topics/fastchat
# [INFO] Visiting https://github.com/chatboxai/chatbox/discussions
# [INFO] Visiting https://github.com/topics/embedding
# [INFO] Visiting https://github.com/topics/pdf
# [INFO] Visiting https://github.com/topics/document-understanding
# [INFO] Visiting https://github.com/chatchat-space/Langchain-Chatchat/discussions
# [INFO] Visiting https://github.com/topics/conversational-bots
# [INFO] Visiting https://github.com/explore
# [INFO] Visiting https://github.com/infiniflow
# [INFO] Visiting https://github.com/topics/discord
# [INFO] Visiting https://github.com/CherryHQ/cherry-studio/discussions
# [INFO] Visiting https://github.com/topics/nodejs
# [INFO] Visiting https://github.com/leon-ai/leon/issues
# [INFO] Visiting https://github.com/topics/ai
# [INFO] Visiting https://github.com/topics/qq
# [INFO] Visiting https://github.com/elizaOS/eliza/pulls
# [INFO] Visiting https://github.com/topics/ai-search
# [INFO] Visiting https://github.com/QuivrHQ/quivr/pulls
# [INFO] Visiting https://github.com/topics/agentic
# [INFO] Visiting https://github.com/Cinnamon/kotaemon/discussions
# [INFO] Visiting https://github.com/topics/wit
# [INFO] Visiting https://github.com/topics/chatglm
# [INFO] Visiting https://github.com/pathwaycom/llm-app/pulls
# [INFO] Visiting https://github.com/topics/anthropic
# [INFO] Visiting https://github.com/topics/macos
# [INFO] Visiting https://github.com/topics/virtual-assistant
# [INFO] Visiting https://github.com/mayooear/ai-pdf-chatbot-langchain/pulls
# [INFO] Visiting https://github.com/yamadashy/repomix/issues
# [INFO] Visiting https://github.com/chatchat-space/Langchain-Chatchat/issues
# [INFO] Visiting https://github.com/topics/machine-learning-library
# [INFO] Visiting https://github.com/topics/chatgpt-api
# [INFO] Visiting https://github.com/topics/personal-assistant
# [INFO] Visiting https://github.com/topics/text2sql
# [INFO] Visiting https://github.com/topics/html
# [INFO] Visiting https://github.com/topics/gemini
# [INFO] Visiting https://github.com/sponsors/wechaty
# [INFO] Visiting https://github.com/topics/chatbots-framework
# [INFO] Visiting https://github.com/topics/javascript
# [INFO] Visiting https://github.com/topics/visual-language-learning
# [INFO] Visiting https://github.com/topics/wechat
# [INFO] Visiting https://github.com/topics/leon
# [INFO] Visiting https://github.com/topics/langchain-chatglm
# [INFO] Visiting https://github.com/yamadashy/repomix
# [INFO] Visiting https://github.com/chatchat-space/Langchain-Chatchat
# [INFO] Visiting https://github.com/topics/mcp-client
# [INFO] Visiting https://github.com/topics/llms
# [INFO] Visiting https://github.com/CherryHQ/cherry-studio/pulls
# [INFO] Visiting https://github.com/topics/plugins
# [INFO] Visiting https://github.com/topics/table-structure-recognition
# [INFO] Visiting https://github.com/topics/electron-app
# [INFO] Visiting https://github.com/topics/frontend
# [INFO] Visiting https://github.com/topics/nlu
# [INFO] Visiting https://github.com/topics/llava
# [INFO] Visiting https://github.com/FlowiseAI/Flowise/pulls
# [INFO] Visiting https://github.com/topics/graphrag
# [INFO] Visiting https://github.com/topics/hugging-face
# [INFO] Visiting https://github.com/topics/spacy
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/docs/README_ko-KR.md
# [INFO] Visiting https://github.com/api-gateway
# [INFO] Visiting https://github.com/cloudformation/home
# [INFO] Visiting https://github.com/codebuild
# [INFO] Visiting https://github.com/37822bec91b3cd4725698b1e8048af93d4388788d295478c98d6ed8e53c92219/68747470733a2f2f696d672e736869656c64732e696f2f6769746875622f6c6963656e73652f6177732d73616d706c65732f626564726f636b2d636861743f7374796c653d666c61742d737175617265
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat.git
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/docs/PUBLISH_API_ms-MY.md
# [INFO] Visiting https://github.com/jp/about-aws/whats-new/2024/06/amazon-opensearch-serverless-entry-cost-half-collection-types
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/docs/ADMINISTRATOR_ms-MY.md
# [INFO] Visiting https://github.
# [INFO] Visiting https://github.com/opensearch-service/features/serverless
# [INFO] Visiting https://github.com/waf
# [INFO] Visiting https://github.com/lambda/pricing
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/docs/README_th-TH.md
# [INFO] Visiting https://github.com/cloudshell/home
# [INFO] Visiting https://github.com/cognito
# [INFO] Visiting https://github.com/k70suK3-k06a7ash1
# [INFO] Visiting https://github.com/s3
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/docs/imgs/fine_grained_permission.png
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/graphs/contributors
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/docs/README_ja-JP.md
# [INFO] Visiting https://github.com/lambda
# [INFO] Visiting https://github.com/i18next/i18next-browser-languageDetector
# [INFO] Visiting https://github.com/bedrock/home
# [INFO] Visiting https://github.com/athena
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/docs/CONTRIBUTING_ms-MY.md
# [INFO] Visiting https://github.com/what-is/retrieval-augmented-generation
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/docs/imgs/admin_bot_menue.png
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/docs/imgs/signin.png
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/raw/refs/heads/v3/docs/README_ms-MY.md
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/docs/LOCAL_DEVELOPMENT_ms-MY.md
# [INFO] Visiting https://github.com/bedrock
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/docs/imgs/customized_bot_creation.png
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/docs/README_id-ID.md
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/docs/imgs/model_screenshot.png
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/README.md
# [INFO] Visiting https://github.com/lambda/latest/dg/snapstart.html
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/commit/e24edba9cf297884f9bfebc8bceba81fb12a8373
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/pull/667
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/tree/e24edba9cf297884f9bfebc8bceba81fb12a8373
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/releases/tag/v2.4.0
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/commit/b8ce89c72da64359c06021c6a9765fbea72841b2
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/docs/LOCAL_DEVELOPMENT.md
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/backend/README.md
# [INFO] Visiting https://github.com/evilmartians/lefthook
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/raw/refs/heads/v3/docs/LOCAL_DEVELOPMENT.md
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/commits/v3/docs/LOCAL_DEVELOPMENT.md
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/forks
# [INFO] Visiting https://github.com/roarkse
# [INFO] Visiting https://github.com/loneizhao/bedrock-claude-chat/forks
# [INFO] Visiting https://github.com/rppth/bedrock-claude-chat/issues
# [INFO] Visiting https://github.com/iakashbhatia/genai-chatbot/forks
# [INFO] Visiting https://github.com/PCG-International/ndc-bedrock-claude-chat/stargazers
# [INFO] Visiting https://github.com/nagineko/bedrock-claude-chat
# [INFO] Visiting https://github.com/network-for-good/bedrock-claude-chat/pulls
# [INFO] Visiting https://github.com/mnmn0/bedrock-claude-chat/forks
# [INFO] Visiting https://github.com/Peter-Lankton/bedrock-claude-chat/pulls
# [INFO] Visiting https://github.com/rizasaputra/bedrock-claude-chat
# [INFO] Visiting https://github.com/Peter-Lankton/bedrock-claude-chat/forks
# [INFO] Visiting https://github.com/mnmn0/bedrock-claude-chat
# [INFO] Visiting https://github.com/joonsun-baek/bedrock-claude-chat/forks
# [INFO] Visiting https://github.com/roarkse/bedrock-claude-chat-pf/forks
# [INFO] Visiting https://github.com/DiUS/bedrock-claude-chat/pulls
# [INFO] Visiting https://github.com/DiUS/bedrock-claude-chat
# [INFO] Visiting https://github.com/mimicarina
# [INFO] Visiting https://github.com/sajee/bedrock-claude-chat/stargazers
# [INFO] Visiting https://github.com/nagineko/bedrock-claude-chat/pulls
# [INFO] Visiting https://github.com/rizasaputra/bedrock-claude-chat/pulls
# [INFO] Visiting https://github.com/joonsun-baek/bedrock-claude-chat/issues
# [INFO] Visiting https://github.com/takat0-h0rikosh1/bedrock-claude-chat/pulls
# [INFO] Visiting https://github.com/j-thurston/mira/pulls
# [INFO] Visiting https://github.com/mnmn0/bedrock-claude-chat/pulls
# [INFO] Visiting https://github.com/RobbyRed98/bedrock-claude-chat/issues
# [INFO] Visiting https://github.com/moritalous
# [INFO] Visiting https://github.com/PCG-International/ndc-bedrock-claude-chat/issues
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/network/members
# [INFO] Visiting https://github.com/iakashbhatia/genai-chatbot/issues
# [INFO] Visiting https://github.com/sajee/bedrock-claude-chat/forks
# [INFO] Visiting https://github.com/j-thurston/mira/forks
# [INFO] Visiting https://github.com/hirosato/bedrock-claude-chat/forks
# [INFO] Visiting https://github.com/sajee
# [INFO] Visiting https://github.com/rlinlen/bedrock-claude-chat/pulls
# ...
# [INFO] Visiting https://github.com/topics/kubernetes-cluster
# [INFO] Visiting https://github.com/budtmo
# [INFO] Visiting https://github.com/aws/aws-cdk
# [INFO] Visiting https://github.com/wiki/Amazon_Web_Services
# [INFO] Visiting https://github.com/bregman-arie/devops-exercises/discussions
# [INFO] Visiting https://github.com/infracost/infracost/discussions
# [INFO] Visiting https://github.com/topics/sso
# [INFO] Visiting https://github.com/topics/dynamodb
# [INFO] Visiting https://github.com/topics/developer-roadmap
# [INFO] Visiting https://github.com/ByteByteGoHq/system-design-101/pulls
# [INFO] Visiting https://github.com/topics/docker-swarm
# [INFO] Visiting https://github.com/topics/cloud-infrastructure
# [INFO] Visiting https://github.com/topics/clone
# [INFO] Visiting https://github.com/pulumi/pulumi
# [INFO] Visiting https://github.com/topics/nginx
# [INFO] Visiting https://github.com/topics/minikube
# [INFO] Visiting https://github.com/infracost/infracost/pulls
# [INFO] Visiting https://github.com/topics/high-availability
# [INFO] Visiting https://github.com/topics/meetup
# [INFO] Visiting https://github.com/topics/security-hardening
# [INFO] Visiting https://github.com/topics/android
# [INFO] Visiting https://github.com/topics/numpy
# [INFO] Visiting https://github.com/topics/google-cloud
# [INFO] Visiting https://github.com/topics/paas
# [INFO] Visiting https://github.com/topics/dall-e-3
# [INFO] Visiting https://github.com/kubernetes-sigs/kubespray/issues
# [INFO] Visiting https://github.com/topics/devops-roadmap
# [INFO] Visiting https://github.com/topics/google-kubernetes
# [INFO] Visiting https://github.com/topics/cloudformation
# [INFO] Visiting https://github.com/topics/php
# [INFO] Visiting https://github.com/topics/hardening
# [INFO] Visiting https://github.com/prowler-cloud/prowler/discussions
# [INFO] Visiting https://github.com/serverless/serverless
# [INFO] Visiting https://github.com/topics/sre
# [INFO] Visiting https://github.com/topics/infrastructure-as-code
# [INFO] Visiting https://github.com/milanm/DevOps-Roadmap/pulls
# [INFO] Visiting https://github.com/ByteByteGoHq/system-design-101
# [INFO] Visiting https://github.com/getsops/sops/discussions
# [INFO] Visiting https://github.com/topics/gcp
# [INFO] Visiting https://github.com/topics/system-design-interview
# [INFO] Visiting https://github.com/topics/cloud-computing
# [INFO] Visiting https://github.com/kubernetes-sigs/kubespray
# [INFO] Visiting https://github.com/topics/emulator
# [INFO] Visiting https://github.com/sponsors/budtmo
# [INFO] Visiting https://github.com/donnemartin/data-science-ipython-notebooks/pulls
# [INFO] Visiting https://github.com/topics/oauth2
# [INFO] Visiting https://github.com/topics/cloud-management
# [INFO] Visiting https://github.com/bregman-arie
# [INFO] Visiting https://github.com/topics/serverless-architectures
# [INFO] Visiting https://github.com/topics/saltstack
# [INFO] Visiting https://github.com/apereo
# [INFO] Visiting https://github.com/topics/ecs
# [INFO] Visiting https://github.com/prowler-cloud/prowler
# [INFO] Visiting https://github.com/danny-avila/LibreChat/issues
# [INFO] Visiting https://github.com/topics/devsecops
# [INFO] Visiting https://github.com/topics/jenkins
# [INFO] Visiting https://github.com/topics/microservice
# [INFO] Visiting https://github.com/localstack/localstack
# [INFO] Visiting https://github.com/topics/novnc
# [INFO] Visiting https://github.com/topics/security-audit
# [INFO] Visiting https://github.com/topics/data-science
# [INFO] Visiting https://github.com/ramitsurana
# [INFO] Visiting https://github.com/topics/node-js
# [INFO] Visiting https://github.com/topics/librechat
# [INFO] Visiting https://github.com/topics/cloud-cost-estimates
# [INFO] Visiting https://github.com/topics/hadoop
# [INFO] Visiting https://github.com/GoogleCloudPlatform
# [INFO] Visiting https://github.com/topics/git
# [INFO] Visiting https://github.com/donnemartin/data-science-ipython-notebooks
# [INFO] Visiting https://github.com/topics/interview
# [INFO] Visiting https://github.com/topics/o1
# [INFO] Visiting https://github.com/topics/tensorflow
# [INFO] Visiting https://github.com/topics/software-development
# [INFO] Visiting https://github.com/topics/webserver
# [INFO] Visiting https://github.com/topics/s3
# [INFO] Visiting https://github.com/topics/spring-boot
# [INFO] Visiting https://github.com/topics/route53
# [INFO] Visiting https://github.com/topics/assistant-api
# [INFO] Visiting https://github.com/topics/grafana
# [INFO] Visiting https://github.com/getsops/sops/issues
# [INFO] Visiting https://github.com/topics/identity-provider
# [INFO] Visiting https://github.com/topics/computer-science
# [INFO] Visiting https://github.com/serverless/serverless/issues
# [INFO] Visiting https://github.com/topics/resource
# [INFO] Visiting https://github.com/aws/aws-cdk/discussions
# [INFO] Visiting https://github.com/aws
# [INFO] Visiting https://github.com/ByteByteGoHq/system-design-101/issues
# [INFO] Visiting https://github.com/topics/pandas
# [INFO] Visiting https://github.com/topics/big-data
# [INFO] Visiting https://github.com/topics/selenium
# [INFO] Visiting https://github.com/caprover
# [INFO] Visiting https://github.com/topics/iac
# [INFO] Visiting https://github.com/donnemartin/awesome-aws/issues
# [INFO] Visiting https://github.com/topics/heroku
# [INFO] Visiting https://github.com/infracost/infracost
# [INFO] Visiting https://github.com/topics/finops
# [INFO] Visiting https://github.com/topics/interview-questions
# [INFO] Visiting https://github.com/topics/kubernetes
# [INFO] Visiting https://github.com/pulumi/pulumi/pulls
# [INFO] Visiting https://github.com/caprover/caprover
# [INFO] Visiting https://github.com/topics/websso
# [INFO] Visiting https://github.com/donnemartin/awesome-aws/pulls
# [INFO] Visiting https://github.com/pulumi
# [INFO] Visiting https://github.com/topics/gce
# [INFO] Visiting https://github.com/topics/kubespray
# [INFO] Visiting https://github.com/topics/docker-android
# [INFO] Visiting https://github.com/caprover/caprover/discussions
# [INFO] Visiting https://github.com/bregman-arie/devops-exercises/pulls
# [INFO] Visiting https://github.com/topics/security-tools
# [INFO] Visiting https://github.com/topics/kinesis
# [INFO] Visiting https://github.com/ramitsurana/awesome-kubernetes
# [INFO] Visiting https://github.com/bregman-arie/devops-exercises/issues
# [INFO] Visiting https://github.com/topics/authentication
# [INFO] Visiting https://github.com/topics/aws-dynamodb
# [INFO] Visiting https://github.com/topics/cis-benchmark
# [INFO] Visiting https://github.com/topics/saml2
# [INFO] Visiting https://github.com/topics/ec2
# [INFO] Visiting https://github.com/infracost
# [INFO] Visiting https://github.com/topics/serverless
# [INFO] Visiting https://github.com/localstack/localstack/issues
# [INFO] Visiting https://github.com/topics/terraform-configurations
# [INFO] Visiting https://github.com/topics/continous-delivery
# [INFO] Visiting https://github.com/topics/k8s-sig-cluster-lifecycle
# [INFO] Visiting https://github.com/budtmo/docker-android/issues
# [INFO] Visiting https://github.com/topics/production-engineer
# [INFO] Visiting https://github.com/topics/bare-metal
# [INFO] Visiting https://github.com/topics/iam
# [INFO] Visiting https://github.com/sponsors/danny-avila
# [INFO] Visiting https://github.com/topics/enterprise-kubernetes-products
# [INFO] Visiting https://github.com/topics/sso-authentication
# [INFO] Visiting https://github.com/localstack
# [INFO] Visiting https://github.com/topics/dotnet
# [INFO] Visiting https://github.com/serverless/serverless/discussions
# [INFO] Visiting https://github.com/topics/node
# [INFO] Visiting https://github.com/topics/azure-functions
# [INFO] Visiting https://github.com/topics/devops
# [INFO] Visiting https://github.com/milanm
# [INFO] Visiting https://github.com/topics/amazon
# [INFO] Visiting https://github.com/topics/books
# [INFO] Visiting https://github.com/danny-avila
# [INFO] Visiting https://github.com/getsops/sops
# [INFO] Visiting https://github.com/topics/authorization
# [INFO] Visiting https://github.com/apereo/cas/pulls
# [INFO] Visiting https://github.com/topics/spark
# [INFO] Visiting https://github.com/ramitsurana/awesome-kubernetes/pulls
# [INFO] Visiting https://github.com/topics/kaggle
# [INFO] Visiting https://github.com/prowler-cloud
# [INFO] Visiting https://github.com/topics/aws-cli
# [INFO] Visiting https://github.com/budtmo/docker-android/pulls
# [INFO] Visiting https://github.com/topics/golang
# [INFO] Visiting https://github.com/ByteByteGoHq
# [INFO] Visiting https://github.com/milanm/DevOps-Roadmap/issues
# [INFO] Visiting https://github.com/prowler-cloud/prowler/issues
# [INFO] Visiting https://github.com/topics/terraform
# [INFO] Visiting https://github.com/topics/aws-sdk
# [INFO] Visiting https://github.com/topics/theano
# [INFO] Visiting https://github.com/topics/fido
# [INFO] Visiting https://github.com/topics/artifacts
# [INFO] Visiting https://github.com/topics/lambda
# [INFO] Visiting https://github.com/topics/gdpr
# [INFO] Visiting https://github.com/topics/azure
# [INFO] Visiting https://github.com/aws/aws-cli/issues
# [INFO] Visiting https://github.com/topics/terraform-cost-estimation
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/pyrightconfig.json
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/commit/d928b44f8055c6a6a8601679e9d76670f33b5b07
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/raw/refs/heads/v3/pyrightconfig.json
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/commits/v3/pyrightconfig.json
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/.gitignore
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/raw/refs/heads/v3/.gitignore
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/commits/v3/.gitignore
# [INFO] Visiting https://github.com/kyosuke-kobayashi-lvgs
# [INFO] Visiting https://github.com/kyosuke-kobayashi-lvgs/javascript
# [INFO] Visiting https://github.com/u/114975044
# [INFO] Visiting https://github.com/clerk/javascript
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/tree/v3/examples
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/tree/v3/examples/agents/tools/bmi
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/pull/321
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/tree/v3/examples/notebooks
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/commits/v3/examples
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/commit/0259c82d6273184a46f81f5f121cf7fd8127c763
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/blob/v3/deploy.yml
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/commits/v3/deploy.yml
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/raw/refs/heads/v3/deploy.yml
# [INFO] Visiting https://github.com/aws-samples/bedrock-chat/commit/0c2aa838b43ff51547dbc5b2d3255bead24a3def
# [INFO] Visiting https://github.com/topics/streaming-response
# [INFO] Visiting https://github.com/topics/langsmith
# [INFO] Visiting https://github.com/sponsors/gabrielfalcao
# [INFO] Visiting https://github.com/topics/template
# [INFO] Visiting https://github.com/reactphp/http
# [INFO] Visiting https://github.com/topics/edge-runtime
# [INFO] Visiting https://github.com/topics/gridfs
# [INFO] Visiting https://github.com/topics/server-side-rendering
# [INFO] Visiting https://github.com/PonomareVlad/grammYVercelEdgeStream/issues
# [INFO] Visiting https://github.com/topics/http-server
# [INFO] Visiting https://github.com/topics/httpretty
# [INFO] Visiting https://github.com/topics/reactphp
# [INFO] Visiting https://github.com/gabrielfalcao/HTTPretty/pulls
# [INFO] Visiting https://github.com/ashleydavis/pdf-server-example/pulls
# [INFO] Visiting https://github.com/topics/express
# [INFO] Visiting https://github.com/topics/http2
# [INFO] Visiting https://github.com/gabrielfalcao
# [INFO] Visiting https://github.com/gabrielfalcao/HTTPretty/issues
# [INFO] Visiting https://github.com/topics/lcel
# [INFO] Visiting https://github.com/trooba/trooba.github.io/pulls
# [INFO] Visiting https://github.com/topics/flow
# [INFO] Visiting https://github.com/topics/akka-http
# [INFO] Visiting https://github.com/topics/chromadb
# [INFO] Visiting https://github.com/topics/preact
# [INFO] Visiting https://github.com/topics/http
# [INFO] Visiting https://github.com/topics/streaming-json
# [INFO] Visiting https://github.com/calvinlfer/Kafka-Akka-HTTP-and-Akka-Streams-integration
# [INFO] Visiting https://github.com/topics/vercel-edge-functions
# [INFO] Visiting https://github.com/janegutou/Streaming-AI-Chatbot-with-Flask-and-React/pulls
# [INFO] Visiting https://github.com/topics/gradio
# [INFO] Visiting https://github.com/grammyjs
# [INFO] Visiting https://github.com/trooba/trooba.github.io/issues
# [INFO] Visiting https://github.com/calvinlfer/Kafka-Akka-HTTP-and-Akka-Streams-integration/issues
# [INFO] Visiting https://github.com/Jayanth-MKV/advanced-rag-cookbooks/pulls
# [INFO] Visiting https://github.com/topics/http-client
# [INFO] Visiting https://github.com/topics/mongodb
# [INFO] Visiting https://github.com/dissorial
# [INFO] Visiting https://github.com/janegutou/Streaming-AI-Chatbot-with-Flask-and-React
# [INFO] Visiting https://github.com/DigitalOptimizationGroup/cloudflare-worker-preact-pwa/pulls
# [INFO] Visiting https://github.com/topics/python2
# [INFO] Visiting https://github.com/topics/tdd
# [INFO] Visiting https://github.com/topics/consumer-group
# [INFO] Visiting https://github.com/ehsan-yar/download-streaming/issues
# [INFO] Visiting https://github.com/calvinlfer/Kafka-Akka-HTTP-and-Akka-Streams-integration/pulls
# [INFO] Visiting https://github.com/calvinlfer/akka-http-streaming-response-examples/pulls
# [INFO] Visiting https://github.com/janegutou
# [INFO] Visiting https://github.com/DigitalOptimizationGroup/cloudflare-worker-preact-pwa
# [INFO] Visiting https://github.com/reactphp/http/issues
# [INFO] Visiting https://github.com/trooba
# [INFO] Visiting https://github.com/sponsors/minhbtrc
# [INFO] Visiting https://github.com/minhbtrc/langchain-chatbot/pulls
# [INFO] Visiting https://github.com/topics/openai-functions
# [INFO] Visiting https://github.com/calvinlfer/akka-http-streaming-response-examples/issues
# [INFO] Visiting https://github.com/reactphp
# [INFO] Visiting https://github.com/topics/actors
# [INFO] Visiting https://github.com/ashleydavis/pdf-server-example/issues
# [INFO] Visiting https://github.com/topics/grpc
# [INFO] Visiting https://github.com/topics/langserve
# [INFO] Visiting https://github.com/topics/pipe
# [INFO] Visiting https://github.com/en/articles/classifying-your-repository-with-topics
# [INFO] Visiting https://github.com/topics/expressjs
# [INFO] Visiting https://github.com/topics/progressive-web-app
# [INFO] Visiting https://github.com/topics/streaming
# [INFO] Visiting https://github.com/topics/akka-streams
# [INFO] Visiting https://github.com/topics/topic
# [INFO] Visiting https://github.com/minhbtrc
# [INFO] Visiting https://github.com/Jayanth-MKV/advanced-rag-cookbooks
# [INFO] Visiting https://github.com/topics/websocket-connection
# [INFO] Visiting https://github.com/vercel
# [INFO] Visiting https://github.com/DigitalOptimizationGroup/cloudflare-worker-preact-pwa/issues
# [INFO] Visiting https://github.com/topics/stream
# [INFO] Visiting https://github.com/Jayanth-MKV/advanced-rag-cookbooks/issues
# [INFO] Visiting https://github.com/topics/decorators
# [INFO] Visiting https://github.com/topics/testing-tools
# [INFO] Visiting https://github.com/topics/preact-cli
# [INFO] Visiting https://github.com/topics/request-flow
# [INFO] Visiting https://github.com/minhbtrc/langchain-chatbot
# [INFO] Visiting https://github.com/PonomareVlad/grammYVercelEdgeStream
# [INFO] Visiting https://github.com/DigitalOptimizationGroup
# [INFO] Visiting https://github.com/sponsors/PonomareVlad
# [INFO] Visiting https://github.com/topics/bedrock
# [INFO] Visiting https://github.com/topics/mock
# [INFO] Visiting https://github.com/calvinlfer/akka-http-streaming-response-examples
# [INFO] Visiting https://github.com/sponsors/ashleydavis
# [INFO] Visiting https://github.com/topics/server-push
# [INFO] Visiting https://github.com/topics/cloudflare-worker
# [INFO] Visiting https://github.com/topics/response-stream
